# %% [markdown]
# """
# Mining Laws RAG System - Kaggle Notebook Version
# ================================================
# Description: Question answering system for Indian mining laws using RAG
# Dataset: https://www.kaggle.com/code/stacky123/embeddings-tokens
#
# Instructions:
# 1. Add the embeddings dataset as input to your notebook
# 2. Install required packages (first cell)
# 3. Run all cells
# 4. Use interactive mode or modify sample questions
# """

# %%
# ============================================================================
# CELL 1: Install Required Packages
# ============================================================================
print(" Installing required packages...")
print("=" * 80)

# Uninstall conflicting versions first
# !pip uninstall -y langchain langchain-community langchain-core -q

# Install compatible versions
# !pip install -q langchain==0.1.20
# !pip install -q langchain-community==0.0.38
# !pip install -q langchain-core==0.1.52
# !pip install -q chromadb==0.4.24
# !pip install -q sentence-transformers==2.3.1
# !pip install -q langchain-groq==0.1.3
# !pip install -q groq

print(" Packages installed successfully!")
print("\n  Please RESTART the kernel after installation!")
print("   Kernel → Restart & Run All\n")
# Out:
#  Installing required packages...
# ================================================================================
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
# ============================================================================
# CELL 2: Import Libraries
# ============================================================================
print("📚 Importing libraries...")

import os
import sys
import json
import warnings
from typing import List, Dict, Optional
from datetime import datetime

warnings.filterwarnings('ignore')

# LangChain imports
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain.prompts import PromptTemplate
from langchain.chains import RetrievalQA
from langchain.schema import Document

# LLM imports
from langchain_groq import ChatGroq

print("✅ Libraries imported successfully!\n")
# Out:
# 📚 Importing libraries...
# ✅ Libraries imported successfully!

# %%
# ============================================================================
# CELL 3: Configuration
# ============================================================================
class RAGConfig:
    """Configuration for RAG system"""
    
    def __init__(self):
        # Kaggle input path - adjust if your dataset is named differently
        self.VECTORSTORE_PATH = "/kaggle/input/embeddingstokens/mining_laws_vectorstore"
        
        # Embedding model (must match the one used to create embeddings)
        self.EMBEDDING_MODEL = "sentence-transformers/all-MiniLM-L6-v2"
        
        # LLM settings
        self.LLM_PROVIDER = "groq"  
        
        # Retrieval settings
        self.TOP_K_RESULTS = 5
        self.SEARCH_TYPE = "similarity"  # or "mmr"
        
        # LLM configurations
        self.LLM_CONFIGS = {
            'groq': {
                'model': 'llama-3.1-8b-instant',
                'temperature': 0.3,
                'max_tokens': 1024
            },
            'openai': {
                'model': 'gpt-4-turbo-preview',
                'temperature': 0.3,
                'max_tokens': 1024
            }
        }
        
        # Output paths
        self.OUTPUT_DIR = "/kaggle/working"
        self.QUERIES_LOG = os.path.join(self.OUTPUT_DIR, "queries_log.json")
    
    def print_config(self):
        """Print configuration"""
        print("\n" + "="*80)
        print("  RAG SYSTEM CONFIGURATION")
        print("="*80)
        print(f" Vector Store:       {self.VECTORSTORE_PATH}")
        print(f" Embedding Model:    {self.EMBEDDING_MODEL}")
        print(f" LLM Provider:       {self.LLM_PROVIDER}")
        print(f" Top-K Results:      {self.TOP_K_RESULTS}")
        print(f" Search Type:        {self.SEARCH_TYPE}")
        
        if self.LLM_PROVIDER in self.LLM_CONFIGS:
            config = self.LLM_CONFIGS[self.LLM_PROVIDER]
            print(f" LLM Model:          {config.get('model', 'N/A')}")
            print(f"  Temperature:        {config.get('temperature', 'N/A')}")
        
        print("="*80 + "\n")


# Initialize configuration
config = RAGConfig()
config.print_config()
# Out:
# ================================================================================
#   RAG SYSTEM CONFIGURATION
# ================================================================================
#  Vector Store:       /kaggle/input/embeddingstokens/mining_laws_vectorstore
#  Embedding Model:    sentence-transformers/all-MiniLM-L6-v2
#  LLM Provider:       groq
#  Top-K Results:      5
#  Search Type:        similarity
#  LLM Model:          llama-3.1-8b-instant
#   Temperature:        0.3
# ================================================================================

# %%
# ============================================================================
# CELL 4: Set API Keys (IMPORTANT!)
# ============================================================================
print(" Setting up API keys...")
print("=" * 80)

from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()

try:
    # Get Groq API key from Kaggle Secrets
    GROQ_API_KEY = user_secrets.get_secret("GROQ_API_KEY")
    os.environ['GROQ_API_KEY'] = GROQ_API_KEY
    print(" Groq API key loaded from Kaggle Secrets")
except Exception as e:
    print(" Groq API key not found in Kaggle Secrets")
    print(f"   Error: {e}")
    print("\n Steps to add your API key:")
    print("1. Go to: https://console.groq.com/keys")
    print("2. Create/copy your API key")
    print("3. In Kaggle: Add-ons > Secrets > Add a new secret")
    print("4. Name it: GROQ_API_KEY")
    print("5. Toggle it ON (blue)")
    print("\n  Cannot proceed without API key!")
    raise

print()
# Out:
#  Setting up API keys...
# ================================================================================
#  Groq API key loaded from Kaggle Secrets

# %%
# ============================================================================
# CELL 5: RAG System Class
# ============================================================================
class MiningLawsRAG:
    """Complete RAG system for mining laws"""
    
    def __init__(self, config: RAGConfig):
        self.config = config
        
        # Load embeddings model
        print(" Loading embedding model...")
        self.embeddings = HuggingFaceEmbeddings(
            model_name=config.EMBEDDING_MODEL,
            model_kwargs={'device': 'cpu'}
        )
        print(" Embedding model loaded\n")
        
        # Load vector store
        self.vectorstore = self._load_vectorstore()
        
        # Initialize LLM
        self.llm = self._initialize_llm()
        
        # Create RAG chain
        self.qa_chain = self._create_rag_chain()
        
        # Query history
        self.query_history = []
    
    def _load_vectorstore(self) -> Chroma:
        """Load the vector store"""
        print(f" Loading vector store from: {self.config.VECTORSTORE_PATH}")
        
        if not os.path.exists(self.config.VECTORSTORE_PATH):
            raise FileNotFoundError(
                f" Vector store not found at {self.config.VECTORSTORE_PATH}\n"
                "Please ensure the embeddings dataset is added as input!"
            )
        
        vectorstore = Chroma(
            persist_directory=self.config.VECTORSTORE_PATH,
            embedding_function=self.embeddings,
            collection_name="mining_laws"
        )
        
        # Test the vectorstore
        collection = vectorstore._collection
        count = collection.count()
        print(f" Vector store loaded successfully!")
        print(f" Total document chunks: {count}\n")
        
        return vectorstore
    
    def _initialize_llm(self):
        """Initialize LLM based on provider"""
        print(f" Initializing LLM: {self.config.LLM_PROVIDER}")
        
        provider = self.config.LLM_PROVIDER
        config_dict = self.config.LLM_CONFIGS.get(provider, {})
        
        if provider == 'groq':
            api_key = os.getenv('GROQ_API_KEY')
            if not api_key:
                raise ValueError(
                    " GROQ_API_KEY not found!\n"
                    "Please set it in Kaggle Secrets or in the API Keys cell."
                )
            
            llm = ChatGroq(
                model=config_dict['model'],
                temperature=config_dict['temperature'],
                max_tokens=config_dict['max_tokens'],
                groq_api_key=api_key
            )
        
        elif provider == 'openai':
            from langchain_openai import ChatOpenAI
            
            api_key = os.getenv('OPENAI_API_KEY')
            if not api_key:
                raise ValueError(
                    " OPENAI_API_KEY not found!\n"
                    "Please set it in Kaggle Secrets or in the API Keys cell."
                )
            
            llm = ChatOpenAI(
                model=config_dict['model'],
                temperature=config_dict['temperature'],
                max_tokens=config_dict['max_tokens'],
                openai_api_key=api_key
            )
        
        else:
            raise ValueError(f"Unsupported LLM provider: {provider}")
        
        print(f" LLM initialized: {config_dict['model']}\n")
        return llm
    
    def _create_rag_chain(self):
        """Create the RAG chain"""
        print(" Creating RAG chain...")
        
        # Custom prompt template
        template =   """You are an expert AI assistant specialized in Indian mining laws and regulations.
                        Your role is to provide accurate, detailed answers based ONLY on the mining legislation documents provided.
                        
                        Context from mining law documents:
                        {context}
                        
                        Question: {question}
                        
                        CRITICAL INSTRUCTIONS:
                        1. Answer ONLY based on the context provided above
                        2. Cite specific acts, sections, regulations, or circulars with exact names
                        3. If the answer is not in the context, clearly state: "I don't have information about this in the available documents."
                        4. Be precise and use proper legal terminology
                        5. Structure your answer clearly with:
                           - Direct answer first
                           - Relevant legal references
                           - Additional context if helpful
                        6. If multiple documents address the question, mention all relevant sources
                        7. For safety or compliance questions, emphasize the specific requirements
                        
                        Detailed Answer:"""
        
        prompt = PromptTemplate(
            template=template,
            input_variables=["context", "question"]
        )
        
        # Create retriever
        retriever = self.vectorstore.as_retriever(
            search_type=self.config.SEARCH_TYPE,
            search_kwargs={"k": self.config.TOP_K_RESULTS}
        )
        
        # Create QA chain
        qa_chain = RetrievalQA.from_chain_type(
            llm=self.llm,
            chain_type="stuff",
            retriever=retriever,
            return_source_documents=True,
            chain_type_kwargs={"prompt": prompt}
        )
        
        print(" RAG chain created\n")
        return qa_chain
    
    def query(self, question: str, show_sources: bool = True) -> Dict:
        """Query the RAG system"""
        
        print("\n" + "="*80)
        print(f" QUESTION: {question}")
        print("="*80 + "\n")
        print(" Searching documents and generating answer...\n")
        
        try:
            # Get answer from RAG chain
            result = self.qa_chain({"query": question})
            
            answer = result['result']
            source_docs = result['source_documents']
            
            # Format answer
            print(" ANSWER:")
            print("-" * 80)
            print(answer)
            print("-" * 80 + "\n")
            
            # Show sources
            if show_sources:
                self._display_sources(source_docs)
            
            # Create result object
            query_result = {
                'question': question,
                'answer': answer,
                'sources': [
                    {
                        'source': doc.metadata.get('source', 'Unknown'),
                        'doc_type': doc.metadata.get('doc_type', 'Unknown'),
                        'subject': doc.metadata.get('subject', 'Unknown'),
                        'year': doc.metadata.get('year', 'Unknown'),
                        'chunk_id': doc.metadata.get('chunk_id', 'Unknown')
                    }
                    for doc in source_docs
                ],
                'timestamp': datetime.now().isoformat(),
                'success': True
            }
            
            # Save to history
            self.query_history.append(query_result)
            
            return query_result
            
        except Exception as e:
            error_msg = f"Error occurred: {str(e)}"
            print(f"\n {error_msg}\n")
            
            query_result = {
                'question': question,
                'answer': error_msg,
                'sources': [],
                'timestamp': datetime.now().isoformat(),
                'success': False,
                'error': str(e)
            }
            
            return query_result
    
    def _display_sources(self, source_docs: List[Document]):
        """Display source documents"""
        print(" SOURCES:")
        print("="*80)
        
        seen_sources = set()
        for idx, doc in enumerate(source_docs, 1):
            source_key = f"{doc.metadata.get('source', 'Unknown')}-{doc.metadata.get('chunk_id', idx)}"
            
            if source_key not in seen_sources:
                print(f"\n[{idx}] {doc.metadata.get('source', 'Unknown')}")
                print(f"    Type: {doc.metadata.get('doc_type', 'Unknown')}")
                print(f"    Subject: {doc.metadata.get('subject', 'Unknown')}")
                print(f"    Year: {doc.metadata.get('year', 'Unknown')}")
                print(f"    Chunk: {doc.metadata.get('chunk_id', '?')}/{doc.metadata.get('chunk_total', '?')}")
                print(f"    Preview: {doc.page_content[:150]}...")
                seen_sources.add(source_key)
        
        print("\n" + "="*80 + "\n")
    
    def get_statistics(self) -> Dict:
        """Get query statistics"""
        if not self.query_history:
            return {"message": "No queries yet"}
        
        successful = sum(1 for q in self.query_history if q['success'])
        failed = len(self.query_history) - successful
        
        return {
            'total_queries': len(self.query_history),
            'successful': successful,
            'failed': failed,
            'success_rate': f"{(successful/len(self.query_history)*100):.1f}%"
        }
    
    def save_query_log(self):
        """Save all queries to JSON file"""
        if not self.query_history:
            print("  No queries to save")
            return
        
        log_path = os.path.join(self.config.OUTPUT_DIR, "queries_log.json")
        with open(log_path, 'w') as f:
            json.dump(self.query_history, f, indent=2)
        
        print(f" Query log saved to: {log_path}")

# %%
# ============================================================================
# CELL 6: Initialize RAG System
# ============================================================================
print("\n" + "="*80)
print("  MINING LAWS RAG SYSTEM - INITIALIZING")
print("="*80)
print(f" Started: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")

try:
    rag_system = MiningLawsRAG(config)
    print(" RAG system initialized successfully!\n")
except Exception as e:
    print(f" Failed to initialize RAG system: {e}")
    raise
# Out:
# ================================================================================
#   MINING LAWS RAG SYSTEM - INITIALIZING
# ================================================================================
#  Started: 2025-11-12 10:58:04
#
#  Loading embedding model...
#  Embedding model loaded
#
#  Loading vector store from: /kaggle/input/embeddingstokens/mining_laws_vectorstore
#  Vector store loaded successfully!
#  Total document chunks: 11109
#
#  Initializing LLM: groq
#  LLM initialized: llama-3.1-8b-instant
#
#  Creating RAG chain...
#  RAG chain created
#
#  RAG system initialized successfully!

# %%
# ============================================================================
# CELL 7: Sample Questions (Modify or add your own!)
# ============================================================================
print("\n" + "="*80)
print(" RUNNING SAMPLE QUESTIONS")
print("="*80 + "\n")

# Modify these questions or add your own
sample_questions = [
    "What are the main provisions of the Mines Act 1952?",
    "What is the minimum age for employment in mines?",
    "What are the safety requirements for underground coal mines?",
    "What is DGMS and what are its functions?",
    "What are the provisions for mine workers' welfare?"
]

# Run all sample questions
results = []
for question in sample_questions:
    result = rag_system.query(question, show_sources=True)
    results.append(result)
    print("\n" + "="*80 + "\n")
# Out:
# ================================================================================
#  RUNNING SAMPLE QUESTIONS
# ================================================================================
#
#
# ================================================================================
#  QUESTION: What are the main provisions of the Mines Act 1952?
# ================================================================================
#
#  Searching documents and generating answer...
#
#  ANSWER:
# --------------------------------------------------------------------------------
# **Main Provisions of the Mines Act 1952:**
#
# The Mines Act 1952 is an Act to amend and consolidate the law relating to the regulation of labour and safety in mines. The main provisions of the Act include:
#
# 1. **Regulation of Labour and Safety**: The Act aims to regulate labour and safety in mines to ensure the well-being of persons employed in the mines.
# 2. **Application of the Act**: The Act applies to the whole of India and comes into force on a date appointed by the Central Government (Section 1, Mines Act 1952).
# 3. **Definition of Mine**: A mine is defined as any operation for the purpose of searching for or obtaining minerals from the earth (Section 2, Mines Act 1952).
# 4. **Responsibility of Mine Owners**: Mine owners are responsible for ensuring the safety of the mine and the life and safety of persons employed in the mine (Section 17(1), Mines Act 1952).
# 5. **Qualifications of Mine Managers**: Mine managers must hold prescribed qualifications to ensure that all work in the mine is carried out in accordance with the provisions of the Mines Act and Regulations (Regulation 34(1), Metalliferous Mines Regulation 1961).
#
# **Relevant Legal References:**
#
# * Section 1, Mines Act 1952
# * Section 2, Mines Act 1952
# * Section 17(1), Mines Act 1952
# * Regulation 34(1), Metalliferous Mines Regulation 1961
#
# **Additional Context:**
#
# The Mines Act 1952 is a comprehensive legislation that aims to regulate labour and safety in mines. The Act requires mine owners to ensure the safety of the mine and the life and safety of persons employed in the mine. The Act also provides for the appointment of mine managers who must hold prescribed qualifications to ensure compliance with the provisions of the Act and Regulations.
#
# **Compliance Requirements:**
#
# To comply with the provisions of the Mines Act 1952, mine owners must:
#
# * Ensure the safety of the mine and the life and safety of persons employed in the mine
# * Appoint a mine manager who holds prescribed qualifications
# * Ensure that all work in the mine is carried out in accordance with the provisions of the Mines Act and Regulations
#
# **Safety Requirements:**
#
# The Mines Act 1952 requires mine owners to ensure the safety of the mine and the life and safety of persons employed in the mine. This includes ensuring that all work in the mine is carried out in accordance with the provisions of the Mines Act and Regulations.
# --------------------------------------------------------------------------------
#
#  SOURCES:
# ================================================================================
#
# [1] THE MINES ACT 1952.pdf
#     Type: Act
#     Subject: General Mining
#     Year: 1952
#     Chunk: 5/190
#     Preview: . CHAPTER X MISCELLANEOUS 82. Decision of question whether a mine is under this Act. 83. Power to exempt from operation of Act, regulations, etc., 84....
#
# [2] THE MINES ACT 1952.pdf
#     Type: Act
#     Subject: General Mining
#     Year: 1952
#     Chunk: 102/190
#     Preview: . [Disputes as to age.] Omitted by the Mines (Amendment) Act, 1959 (62 of 1959), s. 28 (w.e.f. 16-1-1960). 1. Subs. by Act 42 of 1983, s. 24, for sect...
#
# [3] THE MINES ACT 1952.pdf
#     Type: Act
#     Subject: General Mining
#     Year: 1952
#     Chunk: 6/190
#     Preview: . BE it enacted by Parliament as follows:— CHAPTER I PRELIMINARY 1. Short title, extent and commencement.—(1)This Act may be called the Mines Act, 195...
#
# [4] THE MINES CRECHE RULES 1966.pdf
#     Type: Regulation
#     Subject: General Mining
#     Year: 1966
#     Chunk: 0/22
#     Preview: THE MINES CRECHE RULES, 1966 1G.S.R. 516, dated the 1st April, 1966.- In exercise of the powers conferred by clauses (d) and (w) of section 58 of the ...
#
# [5] SANKET NON-COAL MINES 2016-22.pdf
#     Type: Document
#     Subject: Coal Mining
#     Year: 2016
#     Chunk: 320/1096
#     Preview: . ii) the mine been placed under the charge of a manager holding prescribed quilifications as to ensure that all work in the mine was carried on in ac...
#
# ================================================================================
#
#
# ================================================================================
#
#
# ================================================================================
#  QUESTION: What is the minimum age for employment in mines?
# ================================================================================
#
#  Searching documents and generating answer...
#
#  ANSWER:
# --------------------------------------------------------------------------------
# **Minimum Age for Employment in Mines:**
#
# **Direct Answer:** Eighteen years of age.
#
# **Relevant Legal References:**
#
# 1. **Section 40 and Section 17(1) of the Mines Act, 1952**: These sections, read with Regulation 34(1), Regulation 39(1), and Regulation 116(1), of the Metalliferous Mines Regulation, 1961, prohibit the employment of persons below eighteen years of age in mines.
# 2. **Regulation 106(2)(b), Regulation 106(1)(a), Regulation 106(3), Regulation 106(5) of the Metalliferous Mines Regulation, 1961**: These regulations further emphasize the prohibition on employment of persons below eighteen years of age in mines.
# 3. **Employment of persons below eighteen years of age.—(1)After the commencement of the the Mines (Amendment) Act, 1983 (42 of 1983)**: This provision explicitly states that no person below eighteen years of age shall be allowed to work in any mine or part thereof after the commencement of the Mines (Amendment) Act, 1983.
#
# **Additional Context:**
#
# It is essential to note that the Mines (Amendment) Act, 1983, has made significant changes to the Mines Act, 1952, and the Metalliferous Mines Regulation, 1961, to ensure the safety and well-being of mine workers. The minimum age of eighteen years for employment in mines is a critical aspect of these regulations, aimed at protecting the health, safety, and welfare of young workers.
# --------------------------------------------------------------------------------
#
#  SOURCES:
# ================================================================================
#
# [1] SANKET NON-COAL MINES 2016-22.pdf
#     Type: Document
#     Subject: Coal Mining
#     Year: 2016
#     Chunk: 458/1096
#     Preview: eighteen years of age not allowed to work in mine, as required under the provisions of Regulation 106(2)(b), Regulation 106(1)(a), Regulation 106(3), ...
#
# [2] THE MINES ACT 1952.pdf
#     Type: Act
#     Subject: General Mining
#     Year: 1952
#     Chunk: 97/190
#     Preview: . Employment of persons below eighteen years of age.—(1)After the commencement of the the Mines (Amendment) Act, 1983 (42 of 1983), no person below ei...
#
# [3] THE MINES ACT 1952.pdf
#     Type: Act
#     Subject: General Mining
#     Year: 1952
#     Chunk: 100/190
#     Preview: . (2)Every certificate granted by a certifying surgeon on a reference under sub-section (1), shall, for the purpose of this Act, be conclusive evidenc...
#
# [4] THE MINES ACT 1952.pdf
#     Type: Act
#     Subject: General Mining
#     Year: 1952
#     Chunk: 101/190
#     Preview: . Employment of women.—(1)No woman shall, notwithstanding anything contained in any other law, be employed— (a) in any part of a mine which is below g...
#
# [5] SANKET NON-COAL MINES 2016-22.pdf
#     Type: Document
#     Subject: Coal Mining
#     Year: 2016
#     Chunk: 1066/1096
#     Preview: . Had, i) a duly qualified manager has been appointed at the mine for the overall management, control, supervision and direction, as required under th...
#
# ================================================================================
#
#
# ================================================================================
#
#
# ================================================================================
#  QUESTION: What are the safety requirements for underground coal mines?
# ================================================================================
#
#  Searching documents and generating answer...
#
#  ANSWER:
# --------------------------------------------------------------------------------
# **Direct Answer:**
#
# The safety requirements for underground coal mines include:
#
# 1. Providing two exits from every underground workplace, each connected to separate means of egress to the surface.
# 2. Monitoring, assessing, and regularly inspecting the working environment to identify hazards and assess exposure levels.
# 3. Ensuring adequate ventilation for all underground working areas.
# 4. Implementing an operating plan and procedures to ensure a safe system of work and protect workers in zones susceptible to particular hazards.
# 5. Preventing, detecting, and combating fires, explosions, and inundations through measures and precautions appropriate to the nature of the mine operation.
# 6. Stopping operations and evacuating workers to a safe location when there is serious danger to their safety and health.
#
# **Relevant Legal References:**
#
# - Regulation (d) of the Coal Mines Regulations, 1957, which states: "where practicable, provide from every underground workplace, two exits each of which is connected to separate means of egress to the surface."
# - Regulation (e) of the Coal Mines Regulations, 1957, which states: "ensure the monitoring, assessment and regular inspection of the working environment to identify the various hazards to which the workers may be exposed and to assess their level of exposure."
# - Regulation (f) of the Coal Mines Regulations, 1957, which states: "ensure adequate ventilation for all underground working to which access is permitted."
# - Regulation (g) of the Coal Mines Regulations, 1957, which states: "in respect of zones susceptible to particular hazards, draw up and implement an operating plan and procedures to ensure a safe system of work and the protection of workers."
# - Regulation (h) of the Coal Mines Regulations, 1957, which states: "take measures and precautions appropriate to the nature of a mine operation to prevent, detect and combat the start and spread of fires, explosions and inundations."
# - Regulation (i) of the Coal Mines Regulations, 1957, which states: "ensure that, when there is serious danger to the safety and health of workers, operations are stopped and workers are evacuated to a safe location."
#
# **Additional Context:**
#
# It is essential for the management of mines to conduct a risk assessment process to identify and mitigate hazards that could influence the safety and health of workers while installing and maintaining coal/ore handling plants and other heavy structural works. This is in accordance with the provisions of the Coal Mines Regulations, 1957, which emphasize the importance of ensuring a safe system of work and protecting workers from various hazards.
# --------------------------------------------------------------------------------
#
#  SOURCES:
# ================================================================================
#
# [1] COAL MINES REGULATION 2017.pdf
#     Type: Regulation
#     Subject: Coal Mining
#     Year: 2017
#     Chunk: 100/639
#     Preview: ; (d) where practicable, provide from every underground workplace, two exits each of which is connected to separate means of egress to the surface; (e...
#
# [2] DGMS_Annual_Report_2014_Eng-13.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 607/1512
#     Preview: : The management of the mines should conduct a risk assessment process to identify and hazard that could influence the safety and health of workers wh...
#
# [3] DGMS_Annual_Report_2014_Eng-13.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 1365/1512
#     Preview: : The management of the mines should conduct a risk assessment process to identify and hazard that could influence the safety and health of workers wh...
#
# [4] DGMS_Annual_Report_2014_Eng-09.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 415/669
#     Preview: . Provisions of the Coal Mines Regulations, 1957, relating to mine working; explosives and shortfiring; haulage; ventilation; precautions against dang...
#
# [5] DGMS_Annual_Report_2014_Eng-09.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 640/669
#     Preview: . Provisions of the Coal Mines Regulations, 1957, relating to mine working; explosives and shortfiring; haulage; ventilation; precautions against dang...
#
# ================================================================================
#
#
# ================================================================================
#
#
# ================================================================================
#  QUESTION: What is DGMS and what are its functions?
# ================================================================================
#
#  Searching documents and generating answer...
#
#  ANSWER:
# --------------------------------------------------------------------------------
# **Direct Answer:**
# DGMS stands for Directorate General of Mines Safety, which is associated with the Ministry of Labour and Employment, Government of India. Its primary functions include training of Workmen's Inspectors, appointment of Welfare Officers, Workmen's Inspectors, and formation of Safety Committees in mines.
#
# **Relevant Legal References:**
# Although the context does not explicitly mention any specific acts or sections, it is implied that DGMS operates under the provisions of the Mines Act, 1952, and the Factories Act, 1948.
#
# **Additional Context:**
# DGMS is responsible for ensuring the safety and health of workers in mines and factories. The training of Workmen's Inspectors is crucial for effective discharge of their duties. The appointment of Welfare Officers, Workmen's Inspectors, and formation of Safety Committees are essential for maintaining a safe working environment.
#
# **Specific Functions:**
# - Training of Workmen's Inspectors (DGMS Annual Report, 2006, 11 TABLE; DGMS Annual Report, 2012, 11 TABLE; DGMS Annual Report, 2011, 10 TABLE; DGMS Annual Report, 2005, 11 TABLE)
# - Appointment of Welfare Officers, Workmen's Inspectors, and formation of Safety Committees (DGMS Annual Report, 2009)
# - Ensuring the safety and health of workers in mines and factories (implied by the context)
#
# **Emphasis on Safety and Compliance:**
# DGMS plays a crucial role in ensuring compliance with safety regulations in mines and factories. The appointment of Welfare Officers, Workmen's Inspectors, and formation of Safety Committees are essential for maintaining a safe working environment.
# --------------------------------------------------------------------------------
#
#  SOURCES:
# ================================================================================
#
# [1] DGMS_Annual_Report_2014_Eng-06.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 26/202
#     Preview: . DGMS Annual Report,2006 11 TABLE...
#
# [2] DGMS_Annual_Report_2014_Eng-12.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 25/205
#     Preview: . DGMS Annual Report, 2012 11 TABLE...
#
# [3] DGMS_Annual_Report_2014_Eng-11.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 25/206
#     Preview: . DGMS Annual Report, 2011 10 TABLE...
#
# [4] DGMS_Annual_Report_2014_Eng-05.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 24/189
#     Preview: . DGMS Annual Report,2005 11 TABLE...
#
# [5] DGMS_Annual_Report_2014_Eng-09.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 100/669
#     Preview: . DGMS is also associated with training of Workmen‟s Inspectors to make them effective in discharge of their duties. In coal mines almost all the elig...
#
# ================================================================================
#
#
# ================================================================================
#
#
# ================================================================================
#  QUESTION: What are the provisions for mine workers' welfare?
# ================================================================================
#
#  Searching documents and generating answer...
#
#  ANSWER:
# --------------------------------------------------------------------------------
# **Provisions for Mine Workers' Welfare:**
#
# The provisions for mine workers' welfare are outlined in the following sections:
#
# **Welfare Officer:**
# The owner, agent, or manager of a mine shall appoint a suitably qualified person as a Welfare Officer for every mine wherein 500 or more persons are ordinarily employed. The Welfare Officer shall be assisted by one additional Welfare Officer for every additional 2000 persons or part thereof employed. (Source: Rule 2)
#
# **Qualifications of Welfare Officer:**
# No person shall act as a Welfare Officer unless they possess:
# - A university degree
# - A degree or diploma in social science, social work, or labour welfare recognised by the Government
# - Preferably practical experience of handling labour problems in any industrial undertaking for at least three years
# - A knowledge of the language of the district in which the mine is situated or the language understood by the majority of persons employed in the mine (Source: Rule 2)
#
# **Welfare Amenities:**
# The following welfare amenities shall be provided at every mine where more than 50 persons are ordinarily employed:
# - Adequate and suitable shelters for taking food and rest
# - Washing facilities
# - Facilities for storing and drying clothing
# - Facilities for sitting
# - First-aid appliances
# - Canteens
# - Shelters, rest rooms, and lunch rooms
# - Creches (Source: Sections 42-49)
#
# **Leave with Wages:**
# Any person employed in a mine who has been allowed leave for not less than four days shall be paid the wages due for the period of the leave allowed before their leave begins. (Source: Section 54)
#
# **Recovery of Unpaid Wages:**
# Any sum required to be paid by the owner, agent, or manager of a mine under this Chapter but not paid by them shall be recoverable as delayed wages under the provisions of the Payment of Wages Act, 1936 (4 of 1936). (Source: Section 55)
#
# **Exemption from Leave Rules:**
# The Central Government may, by order in writing and subject to such conditions as may be specified therein, exempt the mine from all or any of the provisions of this Chapter if the leave rules applicable to persons employed in the mine provide benefits which are not less favourable than those provided for in this Chapter. (Source: Section 56)
#
# **Additional Context:**
# The provisions for mine workers' welfare are designed to ensure that workers are provided with a safe and healthy working environment, adequate amenities, and fair treatment. The Welfare Officer plays a crucial role in implementing these provisions and ensuring that the needs of mine workers are met.
# --------------------------------------------------------------------------------
#
#  SOURCES:
# ================================================================================
#
# [1] THE MINES RULES 1955.pdf
#     Type: Regulation
#     Subject: General Mining
#     Year: 1955
#     Chunk: 85/147
#     Preview: . Welfare Officer – 2[(1) For every mine wherein 500 or more persons are 3[ordinarily employed] the owner, agent or manager shall appoint a suitably q...
#
# [2] THE MINES RULES 1955.pdf
#     Type: Regulation
#     Subject: General Mining
#     Year: 1955
#     Chunk: 75/147
#     Preview: . 61. Cases of exemption under section 56 - (1) Where an exemption is granted under section 56, the manager shall display at the main entrance of the ...
#
# [3] THE FACTORIES ACT 1948.pdf
#     Type: Act
#     Subject: General Mining
#     Year: 1948
#     Chunk: 3/274
#     Preview: . CHAPTER V WELFARE 42. Washing facilities. 43. Facilities for storing and drying clothing. 3 SECTIONS 44. Facilities for sitting. 45. First-aid appli...
#
# [4] THE FACTORIES ACT 1948.pdf
#     Type: Act
#     Subject: General Mining
#     Year: 1948
#     Chunk: 138/274
#     Preview: . 49. Welfare officers.—(1) In every factory wherein five hundred or more workers are ordinarily employed the occupier shall employ in the factory suc...
#
# [5] THE MINES ACT 1952.pdf
#     Type: Act
#     Subject: General Mining
#     Year: 1952
#     Chunk: 116/190
#     Preview: . 54.Payment in advance in certain cases.—Any person employed in a mine who has been allowed leave for not less than four days, shall, before his leav...
#
# ================================================================================
#
#
# ================================================================================

# %%
# ============================================================================
# CELL 8: Statistics & Save Results
# ============================================================================
print("\n" + "="*80)
print(" SESSION STATISTICS")
print("="*80)

stats = rag_system.get_statistics()
for key, value in stats.items():
    print(f"{key}: {value}")

print("="*80 + "\n")

# Save query log
rag_system.save_query_log()

print(f" Completed: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
# Out:
# ================================================================================
#  SESSION STATISTICS
# ================================================================================
# total_queries: 5
# successful: 5
# failed: 0
# success_rate: 100.0%
# ================================================================================
#
#  Query log saved to: /kaggle/working/queries_log.json
#  Completed: 2025-11-12 10:58:33

# %%
# ============================================================================
# CELL 9: Interactive Query (Optional)
# ============================================================================
# Uncomment the code below to ask your own questions


# Ask your own question
my_question = "What are the penalties for violating mining safety regulations?"

result = rag_system.query(my_question, show_sources=True)

# Access the answer
print("\nYour Answer:")
print(result['answer'])
# Out:
# ================================================================================
#  QUESTION: What are the penalties for violating mining safety regulations?
# ================================================================================
#
#  Searching documents and generating answer...
#
#  ANSWER:
# --------------------------------------------------------------------------------
# **Penalties for Violating Mining Safety Regulations:**
#
# **Direct Answer:**
# The penalties for violating mining safety regulations include imprisonment for a term up to two years, a minimum fine of one lakh rupees per day, and a maximum fine of two lakh rupees for every day during which the failure continues.
#
# **Relevant Legal References:**
# This is as per Section 23 of the mining legislation documents, which states that if any person obstructs or causes any impediment in taking possession or in the management and operation of the Schedule I coal mines, fails to deliver books of account, registers, or any other document, destroys or misuses mine infrastructure or coal stock, or retains any property of such coal mine or removes or destroys it, they shall be punishable with the aforementioned penalties.
#
# **Additional Context:**
# The DGMS Officers also take various actions, including drawing the attention of the mine management about contraventions of statutes, withdrawal of statutory permission, serving an improvement notice, imposition of a prohibitory order, suspension of statutory certificate of competency, prosecution of person(s) held responsible, and punitive action taken departmentally by mining companies.
#
# **Specific Acts, Sections, Regulations, or Circulars:**
# - Section 23 of the mining legislation documents.
# - Regulation 116 of the Metalliferous Mines Regulations, 1961 (for ensuring the safety of persons employed in the mine).
#
# **Note:** The penalties mentioned above are specific to Schedule I coal mines, and the regulations may vary for other types of mines or mining operations.
# --------------------------------------------------------------------------------
#
#  SOURCES:
# ================================================================================
#
# [1] SANKET NON-COAL MINES 2016-22.pdf
#     Type: Document
#     Subject: Coal Mining
#     Year: 2016
#     Chunk: 567/1096
#     Preview: to excercise personal supervision and ensure that all operations in the mine were done in accordance with the provisions of the Mines Act and Regulati...
#
# [2] THE COAL MINES (SPECIAL PROVISIONS) ACT 2015.pdf
#     Type: Act
#     Subject: Coal Mining
#     Year: 2015
#     Chunk: 59/109
#     Preview: . 23. Penalties for certain offences.––If any person— (a) obstructs or causes any impediment in taking possession or in the management and operation o...
#
# [3] DGMS_Annual_Report_2014_Eng-13.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 1134/1512
#     Preview: . A few accidents involving serious bodily injury and most of the important dangerous occurrences are also investigated by DGMS Officers. Arising out ...
#
# [4] DGMS_Annual_Report_2014_Eng-09.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 13/669
#     Preview: . A few accidents involving serious bodily injury and most of the important dangerous occurrences are also investigated by DGMS Officers. Arising out ...
#
# [5] DGMS_Annual_Report_2014_Eng-12.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 11/205
#     Preview: . A few accidents involving serious bodily injury and most of the important dangerous occurrences are also investigated by DGMS Officers. Arising out ...
#
# ================================================================================
#
#
# Your Answer:
# **Penalties for Violating Mining Safety Regulations:**
#
# **Direct Answer:**
# The penalties for violating mining safety regulations include imprisonment for a term up to two years, a minimum fine of one lakh rupees per day, and a maximum fine of two lakh rupees for every day during which the failure continues.
#
# **Relevant Legal References:**
# This is as per Section 23 of the mining legislation documents, which states that if any person obstructs or causes any impediment in taking possession or in the management and operation of the Schedule I coal mines, fails to deliver books of account, registers, or any other document, destroys or misuses mine infrastructure or coal stock, or retains any property of such coal mine or removes or destroys it, they shall be punishable with the aforementioned penalties.
#
# **Additional Context:**
# The DGMS Officers also take various actions, including drawing the attention of the mine management about contraventions of statutes, withdrawal of statutory permission, serving an improvement notice, imposition of a prohibitory order, suspension of statutory certificate of competency, prosecution of person(s) held responsible, and punitive action taken departmentally by mining companies.
#
# **Specific Acts, Sections, Regulations, or Circulars:**
# - Section 23 of the mining legislation documents.
# - Regulation 116 of the Metalliferous Mines Regulations, 1961 (for ensuring the safety of persons employed in the mine).
#
# **Note:** The penalties mentioned above are specific to Schedule I coal mines, and the regulations may vary for other types of mines or mining operations.

# %%
# ============================================================================
# CELL 10: Batch Query Function (Optional)
# ============================================================================
# Use this to query multiple questions at once

def batch_query(questions_list):
    """
    Query multiple questions at once
    
    Usage:
        my_questions = [
            "Question 1?",
            "Question 2?",
            "Question 3?"
        ]
        batch_results = batch_query(my_questions)
    """
    print(f"\n Running batch queries ({len(questions_list)} questions)...\n")
    
    batch_results = []
    for i, question in enumerate(questions_list, 1):
        print(f"\n{'='*80}")
        print(f"Query {i}/{len(questions_list)}")
        print(f"{'='*80}")
        
        result = rag_system.query(question, show_sources=True)
        batch_results.append(result)
    
    return batch_results

# Example usage :

custom_questions = [
    "What are the environmental regulations for mining?",
    "What are the requirements for mine closure?",
    "What are the provisions for compensation in case of mining accidents?"
]

batch_results = batch_query(custom_questions)
# Out:
#  Running batch queries (3 questions)...
#
#
# ================================================================================
# Query 1/3
# ================================================================================
#
# ================================================================================
#  QUESTION: What are the environmental regulations for mining?
# ================================================================================
#
#  Searching documents and generating answer...
#
#  ANSWER:
# --------------------------------------------------------------------------------
# **Environmental Regulations for Mining:**
#
# The environmental regulations for mining are governed by the following provisions:
#
# **Direct Answer:**
#
# The environmental regulations for mining include mine environment monitoring and control, Environment Management Plan (EMP), mine closure plan, and rehabilitation and resettlement (R&R).
#
# **Relevant Legal References:**
#
# * The Mines Act, 1952
# * Mines Rules 1955
# * Coal Mine Regulation, 1957
# * Mines Rescue Rules, 1985
# * Provisions of Indian Electricity Rules, 1956 applicable to mines
# * Vocational Training Rules, 1966
# * Other rules and legislation applicable to opencast metalliferous mines and coal mines
#
# **Additional Context:**
#
# The Environmental Management Plan (EMP) is a crucial document that outlines the measures to be taken to prevent and mitigate environmental impacts of mining operations. The mine closure plan is also an essential component of environmental management, which ensures that the mine is restored to its original state after closure. Rehabilitation and resettlement (R&R) is another critical aspect of environmental management, which involves the rehabilitation of affected areas and the resettlement of displaced communities.
#
# **Specific Provisions:**
#
# * Rule 12 (1) (ii) (d) of the Coal Mines (Conservation and Development) Rules, 1975, deals with the construction of dams.
# * Rule 12 (1) (ii) (e) of the Coal Mines (Conservation and Development) Rules, 1975, deals with artificial barriers.
# * Rule 12 (2) (ii) of the Coal Mines (Conservation and Development) Rules, 1975, deals with improvements in exploration and drilling techniques.
# * Rule 12 (5) (vii) of the Coal Mines (Conservation and Development) Rules, 1975, deals with the development of instruments for measuring and recording mine gases.
#
# **Emphasis on Compliance:**
#
# It is essential for mining operators to comply with these environmental regulations to prevent environmental degradation and ensure the well-being of local communities. Failure to comply with these regulations can result in severe consequences, including fines and penalties.
# --------------------------------------------------------------------------------
#
#  SOURCES:
# ================================================================================
#
# [1] DGMS_Annual_Report_2014_Eng-09.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 346/669
#     Preview: . Environmental Management:- Mine environment monitoring and control; EMP (Environment Management Plan), mine closure plan; R&R (rehabilitation and re...
#
# [2] DGMS_Annual_Report_2014_Eng-09.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 573/669
#     Preview: . Environmental Management:- Mine environment monitoring and control; EMP (Environment Management Plan), mine closure plan; R&R (rehabilitation and re...
#
# [3] THE COAL MINES( CONSERVATION AND DEVELOPMENT) AMENDMENT RULES 2011.pdf
#     Type: Regulation
#     Subject: Coal Mining
#     Year: 2011
#     Chunk: 44/45
#     Preview: . Rule 12 (1) (ii) (d): construction of dams; Rule 12 (1) (ii) (e): artificial barriers. Rule 12 (1) (iii): Special mining techniques obviating sand s...
#
# [4] DGMS_Annual_Report_2014_Eng-09.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 289/669
#     Preview: . Personal Management :- Selection; training and development of human resources; conflict management; sources of conflict; dealing with conflict, moti...
#
# [5] DGMS_Annual_Report_2014_Eng-09.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 616/669
#     Preview: . Environmental Management :- Mine Environment monitoring and control; EMP (Environment Management Plan); mine closure plan; R&R (rehabilitation and r...
#
# ================================================================================
#
#
# ================================================================================
# Query 2/3
# ================================================================================
#
# ================================================================================
#  QUESTION: What are the requirements for mine closure?
# ================================================================================
#
#  Searching documents and generating answer...
#
#  ANSWER:
# --------------------------------------------------------------------------------
# **Requirements for Mine Closure:**
#
# **Direct Answer:**
# The requirements for mine closure include:
#
# 1. Implementation of an approved mine closure plan.
# 2. Surrender of reclaimed leasehold area or structures to the State Government upon issuance of a Mine Closure Compliance Certificate by the Coal Controller.
# 3. Notification of mine closure to the Chief Inspector of Mines, Regional Inspector, and District Magistrate at least 30 days prior to closure.
# 4. Maintenance of protective works and means of entering the mine until satisfactory completion of closure activities.
#
# **Relevant Legal References:**
#
# * Gazette of India: Extraordinary [Part II --- SEC. 3(i)] - Section 18K (Power to Monitor Mine Closure and operate the escrow account formed for funding Mine Closure Activity)
# * Gazette of India: Extraordinary [Part II --- SEC. 3(i)] - Section 18L (Delegation of powers to Coal Controller)
# * The Mines Act, 1952 (available documents) - Section 5 (Notice of abandonment, closure or discontinuance or reopening of mine)
# * The Mines Act, 1952 (available documents) - Section 111 (Working near mine boundaries)
# * The Mines Act, 1952 (available documents) - Section 121 (Working near mine boundaries in belowground mines)
#
# **Additional Context:**
# The Coal Controller or any authorized officer may inspect closure activities and direct additional jobs to be carried out to fulfill the conditions of the Mine Closure Plan (Section 18K). The Coal Controller shall issue a Mine Closure Compliance Certificate upon satisfactory completion of closure activities, which will facilitate surrender of reclaimed leasehold area or structures to the State Government.
#
# **Emphasis on Safety and Compliance:**
# It is essential for mine owners to comply with the requirements for mine closure to ensure safety and prevent environmental hazards. Failure to construct protective works or surrender reclaimed leasehold area may result in the Chief Inspector getting the works executed by another agency, with the cost being defrayed by the mine owner and recoverable as an arrear of land revenue (Section 5 and Section 111).
# --------------------------------------------------------------------------------
#
#  SOURCES:
# ================================================================================
#
# [1] THE COAL MINES( CONSERVATION AND DEVELOPMENT) AMENDMENT RULES 2011.pdf
#     Type: Regulation
#     Subject: Coal Mining
#     Year: 2011
#     Chunk: 39/45
#     Preview: . 18K Power to Monitor Mine Closure and operate the escrow account formed for funding Mine Closure Activity. - The Coal Controller or any other office...
#
# [2] THE METALLIFEROUS MINES REGULATIONS 1961.pdf
#     Type: Regulation
#     Subject: General Mining
#     Year: 1961
#     Chunk: 298/528
#     Preview: . 3[(3)] Notwithstanding anything contained in sub-regulation (1), the Chief Inspector may, by an order in writing and subject to such conditions as h...
#
# [3] The_oil_mines_regulation_2017.pdf
#     Type: Regulation
#     Subject: General Mining
#     Year: 2017
#     Chunk: 32/262
#     Preview: . 5. Notice of abandonment, closure or discontinuance or reopening of mine.- (1) When it is intended to abandon or close a mine or discontinue a mine ...
#
# [4] THE METALLIFEROUS MINES REGULATIONS 1961.pdf
#     Type: Regulation
#     Subject: General Mining
#     Year: 1961
#     Chunk: 296/528
#     Preview: . (2) If the owner fails to construct such protective works within the time specified in the order, the Chief Inspector may get the works executed by ...
#
# [5] COAL MINES REGULATION 2017.pdf
#     Type: Regulation
#     Subject: Coal Mining
#     Year: 2017
#     Chunk: 340/639
#     Preview: . (2) If the owner fails to construct such protective works within the time specified in the order referred to in sub-regulation (1), the Chief Inspec...
#
# ================================================================================
#
#
# ================================================================================
# Query 3/3
# ================================================================================
#
# ================================================================================
#  QUESTION: What are the provisions for compensation in case of mining accidents?
# ================================================================================
#
#  Searching documents and generating answer...
#
#  ANSWER:
# --------------------------------------------------------------------------------
# **Provisions for Compensation in Case of Mining Accidents:**
#
# **Direct Answer:**
#
# The provisions for compensation in case of mining accidents are as follows:
#
# 1. Ex-gratia payment: The amount of ex-gratia payment varies depending on the circumstances of the accident. Initially, Rs. 5 lakhs was paid, which was later enhanced to Rs. 15 lakhs by the Minister of Coal for both contractor workers and permanent workers in Coal India. In the case of natural disasters, the ex-gratia amount has been enhanced to Rs. 35 lakhs since 01/12/2016.
# 2. Compensation under the Employees Compensation Act, 1923: Compensation is awarded as per the provisions of the Employees Compensation Act, 1923, and the Age Factor as mentioned in Schedule IV of the Act.
# 3. Additional benefits for permanent workers: In the case of normal death in harness, a permanent worker is entitled to receive a Life Cover Scheme Amount of Rs. 1,12,800/-, Profit Link Reward of Rs. 55,500/-, etc.
#
# **Relevant Legal References:**
#
# 1. Employees Compensation Act, 1923
# 2. Mines Act, 1952
# 3. Sub-regulation (1) of the relevant regulation (no specific regulation mentioned in the context)
#
# **Additional Context:**
#
# The owner, agent, or manager of the mine is required to give notice of the death or injury to the District Magistrate, the Chief Inspector of Mines, the Regional Inspector, and the competent authority for payment of compensation within 24 hours of being informed of the same. The owner, agent, or manager of the mine is also required to send particulars of the death or injury in the specified Form and method within 7 days of the occurrence and within 15 days of the injured person returning to duty.
#
# **Emphasis on Specific Requirements:**
#
# It is essential to note that the contractor is technically responsible for implementing the Mines Act, 1952, and Regulations and Rules made thereunder, but in practice, the contractor has no control over the statutory persons appointed by ECL, making it impossible for the contractor to implement safety statutes in the mine.
# --------------------------------------------------------------------------------
#
#  SOURCES:
# ================================================================================
#
# [1] Rajmahal Court of Enquiry Report.pdf
#     Type: Report
#     Subject: Legal & Judicial
#     Year: Unknown
#     Chunk: 127/457
#     Preview: . The Hon’ble Court is requested to consider and recommend payment of an ex-gratia amount of Rs. 30 lakhs to the legal heirs of the victim. (v) The Co...
#
# [2] Rajmahal Court of Enquiry Report.pdf
#     Type: Report
#     Subject: Legal & Judicial
#     Year: Unknown
#     Chunk: 354/457
#     Preview: . 202 THE GAZETTE OF INDIA : EXTRAORDINARY [PART II—SEC. 3(ii)] 5. Hence, only Rs. 5 lakhs as Ex-gratia was paid to the deceased contractor workers. 6...
#
# [3] The_oil_mines_regulation_2017.pdf
#     Type: Regulation
#     Subject: General Mining
#     Year: 2017
#     Chunk: 42/262
#     Preview: . (4) If death results from any injury already reported as serious under sub-regulation (1) or if an injury other than the serious injury becomes seri...
#
# [4] Rajmahal Court of Enquiry Report.pdf
#     Type: Report
#     Subject: Legal & Judicial
#     Year: Unknown
#     Chunk: 407/457
#     Preview: . (f) The contractor: (i) As per terms of agreement the contractor was responsible for implementation of the Mines Act, 1952 and Regulations and Rules...
#
# [5] THE MINES ACT 1952.pdf
#     Type: Act
#     Subject: General Mining
#     Year: 1952
#     Chunk: 47/190
#     Preview: . Recovery of expenses.—The Central Government may direct that the expenses of any inquiry conducted by 1[a Committee constituted under section12] sha...
#
# ================================================================================

# %%
# ============================================================================
# END OF NOTEBOOK
# ============================================================================
print("\n" + "="*80)
print(" NOTEBOOK COMPLETED SUCCESSFULLY!")
print("="*80)
print("\n Next Steps:")
print("   1. Review the answers above")
print("   2. Modify sample questions in Cell 7")
print("   3. Use Cell 9 for single custom questions")
print("   4. Use Cell 10 for batch questions")
print("   5. Check /kaggle/working/queries_log.json for saved results")
print("\n" + "="*80 + "\n")
# Out:
# ================================================================================
#  NOTEBOOK COMPLETED SUCCESSFULLY!
# ================================================================================
#
#  Next Steps:
#    1. Review the answers above
#    2. Modify sample questions in Cell 7
#    3. Use Cell 9 for single custom questions
#    4. Use Cell 10 for batch questions
#    5. Check /kaggle/working/queries_log.json for saved results
#
# ================================================================================
