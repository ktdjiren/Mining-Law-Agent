# %% [markdown]
# """
# Mining Laws RAG System - Kaggle Notebook Version
# ================================================
# Description: Question answering system for Indian mining laws using RAG
# Dataset: https://www.kaggle.com/code/stacky123/embeddings-tokens
#
# Instructions:
# 1. Add the embeddings dataset as input to your notebook
# 2. Install required packages (first cell)
# 3. Run all cells
# 4. Use interactive mode or modify sample questions
# """

# %%
# ============================================================================
# CELL 1: Install Required Packages
# ============================================================================
print(" Installing required packages...")
print("=" * 80)

# Uninstall conflicting versions first
# !pip uninstall -y langchain langchain-community langchain-core -q

# Install compatible versions
# !pip install -q langchain==0.1.20
# !pip install -q langchain-community==0.0.38
# !pip install -q langchain-core==0.1.52
# !pip install -q chromadb==0.4.24
# !pip install -q sentence-transformers==2.3.1
# !pip install -q langchain-groq==0.1.3
# !pip install -q groq

print(" Packages installed successfully!")
print("\n  Please RESTART the kernel after installation!")
print("   Kernel → Restart & Run All\n")
# Out:
#  Installing required packages...
# ================================================================================
#  Packages installed successfully!
#
#   Please RESTART the kernel after installation!
#    Kernel → Restart & Run All

# %%
# ============================================================================
# CELL 2: Import Libraries
# ============================================================================
print("📚 Importing libraries...")

import os
import sys
import json
import warnings
from typing import List, Dict, Optional
from datetime import datetime

warnings.filterwarnings('ignore')

# LangChain imports
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain.prompts import PromptTemplate
from langchain.chains import RetrievalQA
from langchain.schema import Document

# LLM imports
from langchain_groq import ChatGroq

print("✅ Libraries imported successfully!\n")
# Out:
# 📚 Importing libraries...
# ✅ Libraries imported successfully!

# %%
# ============================================================================
# CELL 3: Path Diagnostic and Configuration
# ============================================================================
import os
import glob

print("="*80)
print("🔍 DIAGNOSING VECTOR STORE LOCATION")
print("="*80)

# Search for chroma.sqlite3 in the entire input directory
print("\n1️⃣ Searching for chroma.sqlite3 files...")
chroma_files = glob.glob("/kaggle/input/**/**/chroma.sqlite3", recursive=True)

if chroma_files:
    print(f"✅ Found {len(chroma_files)} chroma.sqlite3 file(s):")
    for i, path in enumerate(chroma_files, 1):
        vector_store_path = os.path.dirname(path)
        print(f"\n   [{i}] {vector_store_path}")
        
        # Check what files are in this directory
        files = os.listdir(vector_store_path)
        print(f"       Files: {', '.join(files[:5])}")
        if len(files) > 5:
            print(f"       ... and {len(files)-5} more files")
    
    # Use the first one found
    DETECTED_PATH = os.path.dirname(chroma_files[0])
    print(f"\n✅ Will use: {DETECTED_PATH}")
else:
    print("❌ No chroma.sqlite3 files found!")
    print("\n2️⃣ Let's check what's actually in /kaggle/input/...")
    
    # List the input directory
    if os.path.exists("/kaggle/input"):
        print("\nContents of /kaggle/input/:")
        for item in os.listdir("/kaggle/input"):
            print(f"   📁 {item}")
            
            # Check inside embeddingstokens
            if item == "embeddingstokens":
                emb_path = f"/kaggle/input/{item}"
                print(f"\n   Contents of {emb_path}:")
                for subitem in os.listdir(emb_path):
                    subpath = os.path.join(emb_path, subitem)
                    if os.path.isdir(subpath):
                        print(f"      📁 {subitem}/")
                        # Go one level deeper
                        try:
                            deeper = os.listdir(subpath)
                            for deep_item in deeper[:5]:
                                print(f"         - {deep_item}")
                            if len(deeper) > 5:
                                print(f"         ... and {len(deeper)-5} more items")
                        except:
                            pass
                    else:
                        print(f"      📄 {subitem}")
    
    DETECTED_PATH = None

print("\n" + "="*80)

# Now create the config class
class RAGConfig:
    """Configuration for RAG system"""
    
    def __init__(self, vectorstore_path=None):
        # Use detected path or find it automatically
        if vectorstore_path:
            self.VECTORSTORE_PATH = vectorstore_path
        else:
            # Try to find it automatically
            chroma_files = glob.glob("/kaggle/input/**/**/chroma.sqlite3", recursive=True)
            if chroma_files:
                base_path = os.path.dirname(chroma_files[0])
                
                # Check if we need to go into a UUID subdirectory
                items = os.listdir(base_path)
                
                # Look for directories that look like UUIDs (contain hyphens and are long)
                uuid_dirs = [d for d in items if os.path.isdir(os.path.join(base_path, d)) 
                            and '-' in d and len(d) > 30]
                
                if uuid_dirs:
                    # Check if the UUID directory has more vector store files
                    uuid_path = os.path.join(base_path, uuid_dirs[0])
                    uuid_files = os.listdir(uuid_path)
                    
                    # If UUID dir has data_level0.bin, it's the actual vector store
                    if 'data_level0.bin' in uuid_files:
                        self.VECTORSTORE_PATH = uuid_path
                        print(f"✅ Using UUID subdirectory: {uuid_dirs[0]}\n")
                    else:
                        self.VECTORSTORE_PATH = base_path
                else:
                    self.VECTORSTORE_PATH = base_path
            else:
                raise FileNotFoundError(
                    "❌ Could not find vector store!\n"
                    "Please check the diagnostic output above."
                )
        
        # Embedding model (must match the one used to create embeddings)
        self.EMBEDDING_MODEL = "sentence-transformers/all-MiniLM-L6-v2"
        
        # LLM settings
        self.LLM_PROVIDER = "groq"  
        
        # Retrieval settings
        self.TOP_K_RESULTS = 5
        self.SEARCH_TYPE = "similarity"  
        
        # LLM configurations
        self.LLM_CONFIGS = {
            'groq': {
                'model': 'llama-3.1-8b-instant',
                'temperature': 0.3,
                'max_tokens': 1024
            },
            'openai': {
                'model': 'gpt-4-turbo-preview',
                'temperature': 0.3,
                'max_tokens': 1024
            }
        }
        
        # Output paths
        self.OUTPUT_DIR = "/kaggle/working"
        self.QUERIES_LOG = os.path.join(self.OUTPUT_DIR, "queries_log.json")
    
    def print_config(self):
        """Print configuration"""
        print("\n" + "="*80)
        print("🔧 RAG SYSTEM CONFIGURATION")
        print("="*80)
        print(f"📁 Vector Store Path:")
        print(f"   {self.VECTORSTORE_PATH}")
        
        # Verify path exists
        if os.path.exists(self.VECTORSTORE_PATH):
            print(f"   ✅ Path exists")
            
            # Count files
            files = os.listdir(self.VECTORSTORE_PATH)
            print(f"   ✅ Contains {len(files)} files")
            
            # Check for key files
            required = ['chroma.sqlite3', 'data_level0.bin', 'header.bin']
            found = [f for f in required if os.path.exists(os.path.join(self.VECTORSTORE_PATH, f))]
            print(f"   ✅ Found {len(found)}/{len(required)} required files")
        else:
            print(f"   ❌ Path does not exist!")
        
        print(f"\n🤖 Embedding Model:    {self.EMBEDDING_MODEL}")
        print(f"🧠 LLM Provider:       {self.LLM_PROVIDER}")
        print(f"🔍 Top-K Results:      {self.TOP_K_RESULTS}")
        print(f"🎯 Search Type:        {self.SEARCH_TYPE}")
        
        if self.LLM_PROVIDER in self.LLM_CONFIGS:
            config = self.LLM_CONFIGS[self.LLM_PROVIDER]
            print(f"💬 LLM Model:          {config.get('model', 'N/A')}")
            print(f"🌡️  Temperature:        {config.get('temperature', 'N/A')}")
        
        print("="*80 + "\n")


# Initialize configuration with auto-detected path
try:
    if DETECTED_PATH:
        config = RAGConfig(vectorstore_path=DETECTED_PATH)
        config.print_config()
    else:
        print("\n❌ Cannot initialize config - no vector store found!")
        print("Please check the diagnostic output above.\n")
except Exception as e:
    print(f"\n❌ Error initializing config: {e}\n")
# Out:
# ================================================================================
# 🔍 DIAGNOSING VECTOR STORE LOCATION
# ================================================================================
#
# 1️⃣ Searching for chroma.sqlite3 files...
# ✅ Found 3 chroma.sqlite3 file(s):
#
#    [1] /kaggle/input/embeddingstokens/mining_laws_vectorstore
#        Files: chroma.sqlite3, 66b36f61-38a8-4106-8cce-42ce4d82bc07
#
#    [2] /kaggle/input/embeddingstokens/mining_laws_vectorstore
#        Files: chroma.sqlite3, 66b36f61-38a8-4106-8cce-42ce4d82bc07
#
#    [3] /kaggle/input/embeddingstokens/mining_laws_vectorstore
#        Files: chroma.sqlite3, 66b36f61-38a8-4106-8cce-42ce4d82bc07
#
# ✅ Will use: /kaggle/input/embeddingstokens/mining_laws_vectorstore
#
# ================================================================================
#
# ================================================================================
# 🔧 RAG SYSTEM CONFIGURATION
# ================================================================================
# 📁 Vector Store Path:
#    /kaggle/input/embeddingstokens/mining_laws_vectorstore
#    ✅ Path exists
#    ✅ Contains 2 files
#    ✅ Found 1/3 required files
#
# 🤖 Embedding Model:    sentence-transformers/all-MiniLM-L6-v2
# 🧠 LLM Provider:       groq
# 🔍 Top-K Results:      5
# 🎯 Search Type:        similarity
# 💬 LLM Model:          llama-3.1-8b-instant
# 🌡️  Temperature:        0.3
# ================================================================================

# %%
# ============================================================================
# CELL 4: Set API Keys (IMPORTANT!)
# ============================================================================
print(" Setting up API keys...")
print("=" * 80)

from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()

try:
    # Get Groq API key from Kaggle Secrets
    GROQ_API_KEY = user_secrets.get_secret("GROQ_API_KEY")
    os.environ['GROQ_API_KEY'] = GROQ_API_KEY
    print(" Groq API key loaded from Kaggle Secrets")
except Exception as e:
    print(" Groq API key not found in Kaggle Secrets")
    print(f"   Error: {e}")
    print("\n Steps to add your API key:")
    print("1. Go to: https://console.groq.com/keys")
    print("2. Create/copy your API key")
    print("3. In Kaggle: Add-ons > Secrets > Add a new secret")
    print("4. Name it: GROQ_API_KEY")
    print("5. Toggle it ON (blue)")
    print("\n  Cannot proceed without API key!")
    raise

print()
# Out:
#  Setting up API keys...
# ================================================================================
#  Groq API key loaded from Kaggle Secrets

# %%
# ============================================================================
# CELL 5: RAG System Class
# ============================================================================
class MiningLawsRAG:
    """Complete RAG system for mining laws"""
    
    def __init__(self, config: RAGConfig):
        self.config = config
        
        # Load embeddings model
        print(" Loading embedding model...")
        self.embeddings = HuggingFaceEmbeddings(
            model_name=config.EMBEDDING_MODEL,
            model_kwargs={'device': 'cpu'}
        )
        print(" Embedding model loaded\n")
        
        # Load vector store
        self.vectorstore = self._load_vectorstore()
        
        # Initialize LLM
        self.llm = self._initialize_llm()
        
        # Create RAG chain
        self.qa_chain = self._create_rag_chain()
        
        # Query history
        self.query_history = []
    
    def _load_vectorstore(self) -> Chroma:
        """Load the vector store"""
        print(f" Loading vector store from: {self.config.VECTORSTORE_PATH}")
        
        if not os.path.exists(self.config.VECTORSTORE_PATH):
            raise FileNotFoundError(
                f" Vector store not found at {self.config.VECTORSTORE_PATH}\n"
                "Please ensure the embeddings dataset is added as input!"
            )
        
        vectorstore = Chroma(
            persist_directory=self.config.VECTORSTORE_PATH,
            embedding_function=self.embeddings,
            collection_name="mining_laws"
        )
        
        # Test the vectorstore
        collection = vectorstore._collection
        count = collection.count()
        print(f" Vector store loaded successfully!")
        print(f" Total document chunks: {count}\n")
        
        return vectorstore
    
    def _initialize_llm(self):
        """Initialize LLM based on provider"""
        print(f" Initializing LLM: {self.config.LLM_PROVIDER}")
        
        provider = self.config.LLM_PROVIDER
        config_dict = self.config.LLM_CONFIGS.get(provider, {})
        
        if provider == 'groq':
            api_key = os.getenv('GROQ_API_KEY')
            if not api_key:
                raise ValueError(
                    " GROQ_API_KEY not found!\n"
                    "Please set it in Kaggle Secrets or in the API Keys cell."
                )
            
            llm = ChatGroq(
                model=config_dict['model'],
                temperature=config_dict['temperature'],
                max_tokens=config_dict['max_tokens'],
                groq_api_key=api_key
            )
        
        elif provider == 'openai':
            from langchain_openai import ChatOpenAI
            
            api_key = os.getenv('OPENAI_API_KEY')
            if not api_key:
                raise ValueError(
                    " OPENAI_API_KEY not found!\n"
                    "Please set it in Kaggle Secrets or in the API Keys cell."
                )
            
            llm = ChatOpenAI(
                model=config_dict['model'],
                temperature=config_dict['temperature'],
                max_tokens=config_dict['max_tokens'],
                openai_api_key=api_key
            )
        
        else:
            raise ValueError(f"Unsupported LLM provider: {provider}")
        
        print(f" LLM initialized: {config_dict['model']}\n")
        return llm
    
    def _create_rag_chain(self):
        """Create the RAG chain"""
        print(" Creating RAG chain...")
        
        # Custom prompt template
        template = """You are an expert AI assistant specialized in Indian mining laws and regulations.
        Your role is to provide accurate, comprehensive, and actionable legal analysis based ONLY on the mining legislation documents provided.
        
        Context from mining law documents:
        {context}
        
        Question: {question}
        
        CRITICAL INSTRUCTIONS:
        1. Answer ONLY based on the context provided above
        2. Provide a polished, professional analysis with clear structure
        3. Cite specific acts, sections, regulations, or circulars with exact names and numbers
        4. If the answer is not in the context, clearly state: "I don't have sufficient information about this in the available documents."
        5. Use proper legal terminology while keeping language clear and accessible
        
        RESPONSE STRUCTURE:
        
        For Safety Violation/Incident Analysis:
        
        **INCIDENT OVERVIEW**
        Provide a brief 2-3 line summary of the situation and its severity.
        
        **LEGAL VIOLATIONS IDENTIFIED**
        List each violation clearly with:
        - Specific regulation/section violated
        - What was required by law
        - What actually occurred (the breach)
        - Risk/consequence of the violation
        
        Format: [Regulation] Rule/Section [Number] - [Title/Subject]
        Required: [What the law mandates]
        Violation: [What was not done/wrongly done]
        Risk: [Safety/legal consequences]
        
        **APPLICABLE LEGAL FRAMEWORK**
        Organize by hierarchy:
        1. Primary Legislation (e.g., Mines Act 1952)
           • Relevant sections with brief descriptions
           
        2. Subordinate Regulations (e.g., MMR 1961, CMR 2017)
           • Relevant rules with specific requirements
           
        3. DGMS Circulars/Technical Guidelines (if mentioned)
           • Relevant circulars with procedural mandates
        
        **ROOT CAUSE ANALYSIS**
        Identify systemic failures:
        - Procedural gaps (what processes failed)
        - Supervisory lapses (who failed to ensure compliance)
        - Communication breakdowns (where information flow failed)
        - Training/competency issues (if applicable)
        
        **LEGAL CONSEQUENCES & LIABILITIES**
        - Employer/Management Responsibilities under the law
        - Specific penalty provisions (fines, imprisonment terms if available)
        - Potential charges under different sections
        - Liability of specific roles (Manager, Supervisor, Blaster, etc.)
        
        **CORRECTIVE ACTIONS REQUIRED**
        Provide specific, actionable recommendations:
        
        Immediate Actions:
        - [Specific action 1 with timeline]
        - [Specific action 2 with timeline]
        
        Systemic Improvements:
        - [Process improvement 1]
        - [Training/awareness initiative 2]
        - [Safety system enhancement 3]
        
        Compliance Verification:
        - [Audit/inspection requirement]
        - [Documentation to be maintained]
        - [Reporting obligations to DGMS]
        
        **PREVENTIVE MEASURES**
        Suggest forward-looking safety enhancements:
        - Standard Operating Procedures (SOPs) to implement
        - Safety equipment/systems to install
        - Training programs to conduct
        - Monitoring mechanisms to establish
        
        ---
        
        For General Legal Queries (Non-Violation):
        
        **DIRECT ANSWER**
        Provide clear, direct response to the question in 2-4 sentences.
        
        **LEGAL BASIS**
        - [Act/Regulation] - [Section Number]: [Specific provision]
        - [Supporting regulation/rule with explanation]
        
        **DETAILED EXPLANATION**
        - Elaborate on the legal requirements
        - Explain the rationale behind the provision
        - Clarify any technical terms or procedures
        
        **COMPLIANCE REQUIREMENTS**
        - What must be done (mandatory requirements)
        - Who is responsible
        - Timelines/frequencies if applicable
        - Documentation needed
        
        **PRACTICAL GUIDANCE**
        - Step-by-step compliance approach
        - Common pitfalls to avoid
        - Best practices from the regulations
        
        **RELATED PROVISIONS** (if applicable)
        - Cross-references to connected regulations
        - Additional considerations
        
        ---
        
        FORMATTING GUIDELINES:
        - Use **bold** for main headings
        - Use bullet points (•) for clarity
        - Keep paragraphs concise (3-4 lines max)
        - Distinguish between:
          ✓ Mandatory requirements ("shall", "must") 
          ✓ Recommended practices ("should", "may")
          ✓ Prohibitions ("shall not", "must not")
        - Use tables for comparing multiple requirements (if needed)
        - Highlight critical safety points with ⚠️ WARNING where severe risks exist
        
        TONE:
        - Professional and authoritative
        - Clear and actionable
        - Balanced (cite law, explain risk, suggest solutions)
        - Avoid legal jargon where simpler terms suffice
        - Be empathetic to safety concerns while being legally precise
        
        If information is insufficient, acknowledge limitations clearly and suggest what additional documents/clarifications would help.
        
        Detailed Answer:"""
        
        prompt = PromptTemplate(
            template=template,
            input_variables=["context", "question"]
        )
        
        # Create retriever
        retriever = self.vectorstore.as_retriever(
            search_type=self.config.SEARCH_TYPE,
            search_kwargs={"k": self.config.TOP_K_RESULTS}
        )
        
        # Create QA chain
        qa_chain = RetrievalQA.from_chain_type(
            llm=self.llm,
            chain_type="stuff",
            retriever=retriever,
            return_source_documents=True,
            chain_type_kwargs={"prompt": prompt}
        )
        
        print(" RAG chain created\n")
        return qa_chain
    
    def query(self, question: str, show_sources: bool = True) -> Dict:
        """Query the RAG system"""
        
        print("\n" + "="*80)
        print(f" QUESTION: {question}")
        print("="*80 + "\n")
        print(" Searching documents and generating answer...\n")
        
        try:
            # Get answer from RAG chain
            result = self.qa_chain({"query": question})
            
            answer = result['result']
            source_docs = result['source_documents']
            
            # Format answer
            print(" ANSWER:")
            print("-" * 80)
            print(answer)
            print("-" * 80 + "\n")
            
            # Show sources
            if show_sources:
                self._display_sources(source_docs)
            
            # Create result object
            query_result = {
                'question': question,
                'answer': answer,
                'sources': [
                    {
                        'source': doc.metadata.get('source', 'Unknown'),
                        'doc_type': doc.metadata.get('doc_type', 'Unknown'),
                        'subject': doc.metadata.get('subject', 'Unknown'),
                        'year': doc.metadata.get('year', 'Unknown'),
                        'chunk_id': doc.metadata.get('chunk_id', 'Unknown')
                    }
                    for doc in source_docs
                ],
                'timestamp': datetime.now().isoformat(),
                'success': True
            }
            
            # Save to history
            self.query_history.append(query_result)
            
            return query_result
            
        except Exception as e:
            error_msg = f"Error occurred: {str(e)}"
            print(f"\n {error_msg}\n")
            
            query_result = {
                'question': question,
                'answer': error_msg,
                'sources': [],
                'timestamp': datetime.now().isoformat(),
                'success': False,
                'error': str(e)
            }
            
            return query_result
    
    def _display_sources(self, source_docs: List[Document]):
        """Display source documents"""
        print(" SOURCES:")
        print("="*80)
        
        seen_sources = set()
        for idx, doc in enumerate(source_docs, 1):
            source_key = f"{doc.metadata.get('source', 'Unknown')}-{doc.metadata.get('chunk_id', idx)}"
            
            if source_key not in seen_sources:
                print(f"\n[{idx}] {doc.metadata.get('source', 'Unknown')}")
                print(f"    Type: {doc.metadata.get('doc_type', 'Unknown')}")
                print(f"    Subject: {doc.metadata.get('subject', 'Unknown')}")
                print(f"    Year: {doc.metadata.get('year', 'Unknown')}")
                print(f"    Chunk: {doc.metadata.get('chunk_id', '?')}/{doc.metadata.get('chunk_total', '?')}")
                print(f"    Preview: {doc.page_content[:150]}...")
                seen_sources.add(source_key)
        
        print("\n" + "="*80 + "\n")
    
    def get_statistics(self) -> Dict:
        """Get query statistics"""
        if not self.query_history:
            return {"message": "No queries yet"}
        
        successful = sum(1 for q in self.query_history if q['success'])
        failed = len(self.query_history) - successful
        
        return {
            'total_queries': len(self.query_history),
            'successful': successful,
            'failed': failed,
            'success_rate': f"{(successful/len(self.query_history)*100):.1f}%"
        }
    
    def save_query_log(self):
        """Save all queries to JSON file"""
        if not self.query_history:
            print("  No queries to save")
            return
        
        log_path = os.path.join(self.config.OUTPUT_DIR, "queries_log.json")
        with open(log_path, 'w') as f:
            json.dump(self.query_history, f, indent=2)
        
        print(f" Query log saved to: {log_path}")

# %%
# ============================================================================
# CELL 6: Initialize RAG System
# ============================================================================
print("\n" + "="*80)
print("  MINING LAWS RAG SYSTEM - INITIALIZING")
print("="*80)
print(f" Started: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")

try:
    rag_system = MiningLawsRAG(config)
    print(" RAG system initialized successfully!\n")
except Exception as e:
    print(f" Failed to initialize RAG system: {e}")
    raise
# Out:
# ================================================================================
#   MINING LAWS RAG SYSTEM - INITIALIZING
# ================================================================================
#  Started: 2025-11-14 19:13:23
#
#  Loading embedding model...
# ERROR:chromadb.telemetry.product.posthog:Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# ERROR:chromadb.telemetry.product.posthog:Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given
#  Embedding model loaded
#
#  Loading vector store from: /kaggle/input/embeddingstokens/mining_laws_vectorstore
#  Vector store loaded successfully!
#  Total document chunks: 11109
#
#  Initializing LLM: groq
#  LLM initialized: llama-3.1-8b-instant
#
#  Creating RAG chain...
#  RAG chain created
#
#  RAG system initialized successfully!

# %%
# ============================================================================
# CELL 7: Sample Questions (Modify or add your own!)
# ============================================================================
print("\n" + "="*80)
print(" RUNNING SAMPLE QUESTIONS")
print("="*80 + "\n")

# Modify these questions or add your own
sample_questions = [
    "Analyze this mining safety incident: At an open-cast mine, blasting was conducted at 4:30 PM. Workers in the drilling zone were not notified through siren/horn signals. One contract worker was still within 100 meters of the blasting zone. What are the legal violations and applicable regulations?",
    
    "Evaluate this workplace safety issue: A supervisor instructs an operator to work on a bench that has become 85° steep due to rain collapse. No geotechnical inspection has been done. What laws and rules are being violated?",
    
    "Assess this employment compliance matter: A 16-year-old contract helper is assisting a drill operator in a deep opencast mine. Identify the legal violations and relevant sections of mining laws.",
    
    "Review this environmental compliance case: A mine is producing 1.5 MTPA limestone but expansion clearance (EC) hasn't been renewed for the last 1 year. What are the legal implications and violations?",
    
    "Examine this health and safety scenario: A mine employs 240 workers per shift but runs only one first-aid box. No first-aid room exists. What are the regulatory violations?",
    
    "Analyze this environmental violation: A mine temporarily diverts a natural seasonal stream to develop a haul road without forest/water authority approval. What laws are being breached?",
    
    "Evaluate this storage compliance issue: A mine stores 6,000 litres of diesel in barrels near workshop without PESO license. Identify the legal violations and applicable acts.",
    
    "Assess this underground mining safety incident: A miner enters an unsupported area while cleaning spillage in an underground room-and-pillar mine. What are the safety regulation violations?",
    
    "Review this occupational health matter: Operators using DTH drill machines are not provided ear protection even though noise level is 106 dB. What are the legal violations?",
    
    "Examine this dumping safety violation: Material is being dumped over the edge without maintaining the 10m safety barrier from dump edge. What rules and regulations are being violated?"
]


# Run all sample questions
results = []
for question in sample_questions:
    result = rag_system.query(question, show_sources=True)
    results.append(result)
    print("\n" + "="*80 + "\n")
# Out:
# ================================================================================
#  RUNNING SAMPLE QUESTIONS
# ================================================================================
#
#
# ================================================================================
#  QUESTION: Analyze this mining safety incident: At an open-cast mine, blasting was conducted at 4:30 PM. Workers in the drilling zone were not notified through siren/horn signals. One contract worker was still within 100 meters of the blasting zone. What are the legal violations and applicable regulations?
# ================================================================================
#
#  Searching documents and generating answer...
#
#  ANSWER:
# --------------------------------------------------------------------------------
# **INCIDENT OVERVIEW**
#
# At an open-cast mine, blasting was conducted at 4:30 PM without proper notification to workers in the drilling zone through siren/horn signals. A contract worker remained within 100 meters of the blasting zone, putting their life at risk.
#
# **LEGAL VIOLATIONS IDENTIFIED**
#
# 1. **Regulation 160(1) of the Metalliferous Mines Regulations, 1961** - **Notification of Blasting Operations**
#    Required: The charging of holes must be carried out by or under the personal supervision of a competent person/blaster, and the area must be notified to the workmen through siren/horn signals.
#    Violation: The area was not notified to the workmen, and a contract worker remained within 100 meters of the blasting zone.
#    Risk: The worker's life was at risk due to the lack of notification.
#
# 2. **Regulation 34(1) of the Metalliferous Mines Regulations, 1961** - **Supervision of Blasting Operations**
#    Required: The working of the mine must be placed under the supervision of a duly qualified person appointed as manager.
#    Violation: The manager failed to ensure that the area was notified to the workmen, and a contract worker remained within 100 meters of the blasting zone.
#    Risk: The worker's life was at risk due to the lack of supervision.
#
# **APPLICABLE LEGAL FRAMEWORK**
#
# 1. **Primary Legislation: Mines Act, 1952**
#    • Section 18(4) - Requires the working of the mine to be placed under the supervision of a duly qualified person appointed as manager.
#    • Section 17(1) - Requires a duly qualified manager to be appointed for overall management, control, supervision, and direction of the mine.
#
# 2. **Subordinate Regulations: Metalliferous Mines Regulations, 1961**
#    • Regulation 34(1) - Requires the working of the mine to be placed under the supervision of a duly qualified person appointed as manager.
#    • Regulation 160(1) - Requires the charging of holes to be carried out by or under the personal supervision of a competent person/blaster and the area to be notified to the workmen through siren/horn signals.
#
# **ROOT CAUSE ANALYSIS**
#
# * Procedural gaps: The manager failed to ensure that the area was notified to the workmen, and a contract worker remained within 100 meters of the blasting zone.
# * Supervisory lapses: The manager failed to supervise the blasting operations properly.
# * Communication breakdowns: The workmen were not notified through siren/horn signals, and the contract worker remained within 100 meters of the blasting zone.
#
# **LEGAL CONSEQUENCES & LIABILITIES**
#
# * Employer/Management Responsibilities under the law: The employer/management is responsible for ensuring that the mine is operated in a safe manner and that the workmen are notified of blasting operations.
# * Specific penalty provisions: The employer/management may be liable for fines and imprisonment under the Mines Act, 1952.
# * Potential charges under different sections: The employer/management may be charged under Section 18(4) and Section 17(1) of the Mines Act, 1952.
# * Liability of specific roles: The manager is liable for the failure to supervise the blasting operations properly and for failing to ensure that the area was notified to the workmen.
#
# **CORRECTIVE ACTIONS REQUIRED**
#
# Immediate Actions:
#
# * Conduct an investigation into the incident and identify the root causes.
# * Ensure that the manager and other personnel involved in the incident are properly trained and aware of their responsibilities.
# * Implement a system to ensure that workmen are notified of blasting operations through siren/horn signals.
#
# Systemic Improvements:
#
# * Develop and implement a comprehensive safety manual that outlines the procedures for blasting operations.
# * Conduct regular safety audits and inspections to ensure that the mine is operated in a safe manner.
# * Provide regular training to workmen on safety procedures and protocols.
#
# Compliance Verification:
#
# * Conduct regular audits and inspections to ensure that the mine is operated in compliance with the regulations.
# * Maintain accurate records of safety inspections, audits, and training programs.
# * Report any incidents or near-misses to the DGMS.
#
# **PREVENTIVE MEASURES**
#
# * Standard Operating Procedures (SOPs) to implement:
#  + Develop and implement a comprehensive SOP for blasting operations that outlines the procedures for notification of workmen.
#  + Develop and implement a SOP for regular safety audits and inspections.
# * Safety equipment/systems to install:
#  + Install a system for notification of workmen through siren/horn signals.
#  + Install a system for regular safety audits and inspections.
# * Training programs to conduct:
#  + Conduct regular training programs for workmen on safety procedures and protocols.
#  + Conduct regular training programs for managers and other personnel on their responsibilities and liabilities.
# * Monitoring mechanisms to establish:
#  + Establish a system for monitoring and reporting incidents and near-misses.
#  + Establish a system for monitoring and reporting compliance with regulations.
# --------------------------------------------------------------------------------
#
#  SOURCES:
# ================================================================================
#
# [1] SANKET NON-COAL MINES 2016-22.pdf
#     Type: Document
#     Subject: Coal Mining
#     Year: 2016
#     Chunk: 309/1096
#     Preview: . Had, 107 Statistical Analysis & Numbers: Key Evaluation of Trends in Non-Coal Mine Accidents SANKET The working of the mine been placed, under the s...
#
# [2] SANKET NON-COAL MINES 2016-22.pdf
#     Type: Document
#     Subject: Coal Mining
#     Year: 2016
#     Chunk: 305/1096
#     Preview: . Had, i) a duly qualified Manager been appointed for overall management, control, supervision and direction of the mine as required under Regulation ...
#
# [3] SANKET COAL MINES 2016-22.pdf
#     Type: Document
#     Subject: Coal Mining
#     Year: 2016
#     Chunk: 722/984
#     Preview: . Had, i. the work persons been not slept whilst on duty as required under Regulation 40 (7) of the Coal Mines Regulations, 2017, ii. the work persons...
#
# [4] SANKET NON-COAL MINES 2016-22.pdf
#     Type: Document
#     Subject: Coal Mining
#     Year: 2016
#     Chunk: 897/1096
#     Preview: . Manager, Mine Forman, Mining Mate & Blaster were appointed for supervision of the mining operations including blasting in the mine as required under...
#
# [5] DGMS_Annual_Report_2014_Eng-09.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 640/669
#     Preview: . Provisions of the Coal Mines Regulations, 1957, relating to mine working; explosives and shortfiring; haulage; ventilation; precautions against dang...
#
# ================================================================================
#
#
# ================================================================================
#
#
# ================================================================================
#  QUESTION: Evaluate this workplace safety issue: A supervisor instructs an operator to work on a bench that has become 85° steep due to rain collapse. No geotechnical inspection has been done. What laws and rules are being violated?
# ================================================================================
#
#  Searching documents and generating answer...
#
#  ANSWER:
# --------------------------------------------------------------------------------
# **INCIDENT OVERVIEW**
#
# A supervisor instructs an operator to work on a bench that has become 85° steep due to rain collapse. No geotechnical inspection has been done, posing a significant risk to the operator's safety.
#
# **LEGAL VIOLATIONS IDENTIFIED**
#
# • **Regulation 114(1)** - Steep Workings:
#   Required: Adequate precautions shall be taken to prevent danger to persons from falling or rolling of timber, tools, or other appliances or material in workings having an inclination of 30 degrees or more from the horizontal.
#   Violation: The bench has become 85° steep, exceeding the 30-degree threshold, and no precautions have been taken.
#   Risk: The operator is at risk of falling or being injured by rolling or falling objects.
#
# • **Regulation 114(2)** - Steep Workings:
#   Required: No person shall work or be permitted to work at any place having an inclination of 45 degrees or more from the horizontal, where he is likely to slip or overbalance, unless he is secured by a safety belt or life line or is otherwise safeguarded.
#   Violation: The bench has become 85° steep, exceeding the 45-degree threshold, and no safety measures have been taken.
#   Risk: The operator is at risk of slipping or overbalancing and falling.
#
# • **Regulation 105(1)(a)** - Manual Opencast Working:
#   Required: In alluvial soil, morum, gravel, clay, debris, or other similar ground, the sides shall be sloped at an angle of safety not exceeding 45 degrees from the horizontal or such other angle as the Regional Inspector may permit by an order in writing and subject to such conditions as he may specify therein.
#   Violation: The bench has become 85° steep, exceeding the 45-degree threshold, and no permission has been obtained from the Regional Inspector.
#   Risk: The operator is at risk of falling or being injured by rolling or falling objects.
#
# **APPLICABLE LEGAL FRAMEWORK**
#
# 1. **Primary Legislation (Mines Act 1952)**
#    • Relevant sections: Sections related to safety, health, and welfare of miners.
#
# 2. **Subordinate Regulations (Coal Mines Regulations, 2017)**
#    • Relevant rules: Regulations 114, 105, and other related provisions.
#
# 3. **DGMS Circulars/Technical Guidelines**
#    • None mentioned in the provided context.
#
# **ROOT CAUSE ANALYSIS**
#
# - **Procedural gaps**: No geotechnical inspection has been done, and the supervisor has instructed the operator to work on the steep bench without taking necessary precautions.
# - **Supervisory lapses**: The supervisor has failed to ensure compliance with safety regulations and has put the operator at risk.
# - **Communication breakdowns**: There is a lack of communication between the supervisor and the operator regarding the safety risks associated with working on the steep bench.
# - **Training/competency issues**: The supervisor and the operator may not have received adequate training on safety procedures and regulations.
#
# **LEGAL CONSEQUENCES & LIABILITIES**
#
# - **Employer/Management Responsibilities**: The employer/management is responsible for ensuring compliance with safety regulations and providing a safe working environment.
# - **Specific penalty provisions**: Fines and imprisonment terms may be applicable under the Mines Act 1952 and the Coal Mines Regulations, 2017.
# - **Potential charges**: Charges may be brought against the employer/management, supervisor, and operator under various sections of the Mines Act 1952 and the Coal Mines Regulations, 2017.
# - **Liability of specific roles**: The supervisor and the operator may be held liable for their actions, and the employer/management may be held liable for failing to ensure compliance with safety regulations.
#
# **CORRECTIVE ACTIONS REQUIRED**
#
# - **Immediate Actions**:
#   • Stop work on the steep bench immediately.
#   • Conduct a geotechnical inspection to assess the stability of the bench.
#   • Take necessary precautions to ensure the safety of the operator and other personnel.
# - **Systemic Improvements**:
#   • Develop and implement a safety protocol for working on steep benches.
#   • Provide training to supervisors and operators on safety procedures and regulations.
#   • Conduct regular safety inspections to ensure compliance with regulations.
# - **Compliance Verification**:
#   • Conduct audits and inspections to verify compliance with safety regulations.
#   • Maintain documentation of safety protocols, training, and inspections.
#   • Report any non-compliance to the DGMS.
#
# **PREVENTIVE MEASURES**
#
# - **Standard Operating Procedures (SOPs)**: Develop and implement SOPs for working on steep benches.
# - **Safety equipment/systems**: Install safety equipment such as guardrails, fences, or ropes to prevent falls.
# - **Training programs**: Conduct regular training programs for supervisors and operators on safety procedures and regulations.
# - **Monitoring mechanisms**: Establish monitoring mechanisms to ensure compliance with safety regulations and to identify potential hazards.
# --------------------------------------------------------------------------------
#
#  SOURCES:
# ================================================================================
#
# [1] SANKET COAL MINES 2016-22.pdf
#     Type: Document
#     Subject: Coal Mining
#     Year: 2016
#     Chunk: 898/984
#     Preview: . the height of the bench not been exceeded three meters as required under the provision of the Regulation 106(4) of the Coal Mines Regulations, 2017;...
#
# [2] THE METALLIFEROUS MINES REGULATIONS 1961.pdf
#     Type: Regulation
#     Subject: General Mining
#     Year: 1961
#     Chunk: 359/528
#     Preview: . (c) Except where otherwise permitted by the Chief Inspector by an order in writing and subject to such conditions as he may specify therein, no such...
#
# [3] SANKET NON-COAL MINES 2016-22.pdf
#     Type: Document
#     Subject: Coal Mining
#     Year: 2016
#     Chunk: 623/1096
#     Preview: . 196 Statistical Analysis & Numbers: Key Evaluation of Trends in Non-Coal Mine Accidents SANKET Had, i) the person been not deployed or travelled on ...
#
# [4] COAL MINES REGULATION 2017.pdf
#     Type: Regulation
#     Subject: Coal Mining
#     Year: 2017
#     Chunk: 309/639
#     Preview: . 105. Manual opencast working.– In manual opencast workings, the following precautions shall be observed, namely: - (1) In alluvial soil, morum, grav...
#
# [5] THE METALLIFEROUS MINES REGULATIONS 1961.pdf
#     Type: Regulation
#     Subject: General Mining
#     Year: 1961
#     Chunk: 302/528
#     Preview: . 114. Steep workings – (1) In workings having an inclination of 30 degrees or more from the horizontal adequate precautions shall be taken to prevent...
#
# ================================================================================
#
#
# ================================================================================
#
#
# ================================================================================
#  QUESTION: Assess this employment compliance matter: A 16-year-old contract helper is assisting a drill operator in a deep opencast mine. Identify the legal violations and relevant sections of mining laws.
# ================================================================================
#
#  Searching documents and generating answer...
#
#  ANSWER:
# --------------------------------------------------------------------------------
# **INCIDENT OVERVIEW**
#
# A 16-year-old contract helper is assisting a drill operator in a deep opencast mine, violating age restrictions and posing a significant risk to the helper's safety and the safety of others in the mine.
#
# **LEGAL VIOLATIONS IDENTIFIED**
#
# 1. **Regulation 106(2)(b) of the Metalliferous Mines Regulations, 1961** - Persons below 18 years of age shall not be allowed to work in a mine.
#    Required: No persons below 18 years of age shall be allowed to work in a mine.
#    Violation: A 16-year-old contract helper is assisting a drill operator in the mine.
#    Risk: The helper's safety and the safety of others in the mine are at risk due to the helper's inexperience and lack of training.
#
# 2. **Regulation 106(1)(a) of the Metalliferous Mines Regulations, 1961** - The sides of opencast workings shall be benched, sloped, and secured to prevent danger from the fall of sides.
#    Required: The sides of opencast workings shall be benched, sloped, and secured.
#    Violation: The regulation is not mentioned to be violated in the context, but it is essential to ensure the safety of the mine.
#    Risk: The safety of the mine and its workers is at risk due to the potential collapse of the mine's sides.
#
# 3. **Regulation 106(3) of the Metalliferous Mines Regulations, 1961** - The undercutting of the side of the bench shall not be permitted to cause overhang.
#    Required: The undercutting of the side of the bench shall not be permitted.
#    Violation: The regulation is not mentioned to be violated in the context, but it is essential to ensure the safety of the mine.
#    Risk: The safety of the mine and its workers is at risk due to the potential collapse of the mine's sides.
#
# **APPLICABLE LEGAL FRAMEWORK**
#
# 1. **Primary Legislation (Mines Act, 1952)**
#    • Section 17(1) - The mine shall be placed under the charge of a duly qualified manager to ensure that all activity in the mine is carried on in accordance with the provisions of the Act and the regulations, rules, bye-laws, and orders made thereunder.
#    • Section 17(1) read with Regulation 32(1) of the Metalliferous Mines Regulations, 1961 - The mine shall be placed under the charge of a duly qualified manager to ensure the safety of persons employed in the mine.
#
# 2. **Subordinate Regulations (Metalliferous Mines Regulations, 1961)**
#    • Regulation 106(1) - The sides of opencast workings shall be benched, sloped, and secured to prevent danger from the fall of sides.
#    • Regulation 106(2) - The opencast workings shall be adequately benched, sloped, and secured to prevent danger from the fall of sides.
#    • Regulation 106(3) - The undercutting of the side of the bench shall not be permitted to cause overhang.
#    • Regulation 106(5) - The opencast workings shall be adequately benched, sloped, and secured to prevent danger from the fall of sides.
#
# **ROOT CAUSE ANALYSIS**
#
# - **Procedural gaps**: The mine management failed to ensure that all workers, including contract helpers, are above 18 years of age and have the necessary training and experience.
# - **Supervisory lapses**: The supervisors failed to monitor the mine's activities and ensure compliance with the regulations.
# - **Communication breakdowns**: The mine management failed to communicate the regulations and safety procedures to the contract helpers.
# - **Training/competency issues**: The contract helpers may not have received the necessary training and experience to work in the mine.
#
# **LEGAL CONSEQUENCES & LIABILITIES**
#
# - **Employer/Management Responsibilities**: The mine management is responsible for ensuring compliance with the regulations and the safety of all workers, including contract helpers.
# - **Specific penalty provisions**: The mine management may face fines and imprisonment under Section 31 of the Mines Act, 1952, for violating the regulations.
# - **Potential charges**: The mine management may face charges under Section 31 of the Mines Act, 1952, for violating the regulations.
# - **Liability of specific roles**: The mine manager, supervisors, and other officials may be held liable for violating the regulations.
#
# **CORRECTIVE ACTIONS REQUIRED**
#
# - **Immediate Actions**:
#   - Ensure that all contract helpers are above 18 years of age and have the necessary training and experience.
#   - Conduct a thorough investigation into the incident and take corrective action.
# - **Systemic Improvements**:
#   - Develop and implement a comprehensive training program for all workers, including contract helpers.
#   - Establish a system for monitoring and enforcing compliance with the regulations.
#   - Improve communication
# --------------------------------------------------------------------------------
#
#  SOURCES:
# ================================================================================
#
# [1] SANKET NON-COAL MINES 2016-22.pdf
#     Type: Document
#     Subject: Coal Mining
#     Year: 2016
#     Chunk: 566/1096
#     Preview: . Had i) the sides of the opencast workings been kept benched, sloped and secured whilst working the mine so as to prevent danger from fall of sides, ...
#
# [2] SANKET NON-COAL MINES 2016-22.pdf
#     Type: Document
#     Subject: Coal Mining
#     Year: 2016
#     Chunk: 257/1096
#     Preview: . Had, i) The sides of opencast workings been benched or kept sloped at an angle of safety not exceeding 60 degrees from horizontal, or kept secured a...
#
# [3] SANKET NON-COAL MINES 2016-22.pdf
#     Type: Document
#     Subject: Coal Mining
#     Year: 2016
#     Chunk: 457/1096
#     Preview: . Had, i) condiions specifying to work the mine with help of heavy machineries for digging, excavation and removal been obtained and necessary precaut...
#
# [4] COAL MINES REGULATION 2017.pdf
#     Type: Regulation
#     Subject: Coal Mining
#     Year: 2017
#     Chunk: 106/639
#     Preview: . 39. Responsibilities of contractor.– (1) A contractor deployed in a mine for any work shall- (a) establish effective ongoing communication and co-or...
#
# [5] Rajmahal Court of Enquiry Report.pdf
#     Type: Report
#     Subject: Legal & Judicial
#     Year: Unknown
#     Chunk: 169/457
#     Preview: . Contractor should also ensure that such supervisors are constantly in touch with the Safety Officer of the mine and works as per his guidance. Howev...
#
# ================================================================================
#
#
# ================================================================================
#
#
# ================================================================================
#  QUESTION: Review this environmental compliance case: A mine is producing 1.5 MTPA limestone but expansion clearance (EC) hasn't been renewed for the last 1 year. What are the legal implications and violations?
# ================================================================================
#
#  Searching documents and generating answer...
#
#  ANSWER:
# --------------------------------------------------------------------------------
# **INCIDENT OVERVIEW**
# A mine is producing 1.5 MTPA limestone but expansion clearance (EC) hasn't been renewed for the last 1 year, posing a risk of non-compliance with environmental regulations.
#
# **LEGAL VIOLATIONS IDENTIFIED**
#
# • **Mines and Minerals (Development and Regulation) Amendment Act, 2015** - Section 10(6) - Extension of lease period for mineral used for other than captive purpose
#   Required: The lease period should be extended up to a period ending on the 31st March, 2020, with effect from the date of expiry of the period of renewal last made or till the completion of renewal period, if any, or a period of fifty years from the date of grant of such lease, whichever is later.
#   Violation: The expansion clearance (EC) hasn't been renewed for the last 1 year, potentially breaching the lease extension requirements.
#   Risk: Non-compliance with environmental regulations and potential penalties.
#
# • **Mines and Minerals (Development and Regulation) Amendment Act, 2015** - Section 10(7) - Right of first refusal at the time of auction held for such lease after the expiry of the lease period
#   Required: Any holder of a lease granted, where mineral is used for captive purpose, shall have the right of first refusal at the time of auction held for such lease after the expiry of the lease period.
#   Violation: The mine is producing limestone without a renewed expansion clearance (EC), potentially breaching the right of first refusal.
#   Risk: Loss of rights and potential penalties.
#
# **APPLICABLE LEGAL FRAMEWORK**
#
# 1. **Primary Legislation**
#    • **Mines and Minerals (Development and Regulation) Amendment Act, 2015** - Section 10: Provides for the extension of lease period and right of first refusal.
#    • **Mines and Minerals (Development and Regulation) Amendment Act, 2021** - Section 12: Introduces the concept of additional amount for mineral produced after the commencement of the Act.
#
# 2. **Subordinate Regulations**
#    • **Mines Rules, 2016** - Rule 16: Requires the holder of a mining lease to obtain an environmental clearance (EC) before commencing mining operations.
#    • **Environmental Impact Assessment (EIA) Notification, 2006** - Rule 5: Mandates the preparation of an environmental impact assessment (EIA) report for mining projects.
#
# 3. **DGMS Circulars/Technical Guidelines**
#    • **DGMS Circular No. 17 of 2018**: Provides guidelines for the implementation of environmental regulations in mines.
#
# **ROOT CAUSE ANALYSIS**
#
# • Procedural gaps: The mine may not have followed the necessary procedures for renewing the expansion clearance (EC) and obtaining environmental clearance (EC).
# • Supervisory lapses: The management or supervisors may not have ensured compliance with environmental regulations.
# • Communication breakdowns: There may have been a lack of communication between the mine management and regulatory authorities.
# • Training/competency issues: The mine staff may not have received adequate training on environmental regulations and procedures.
#
# **LEGAL CONSEQUENCES & LIABILITIES**
#
# • Employer/Management Responsibilities under the law: The mine management is responsible for ensuring compliance with environmental regulations.
# • Specific penalty provisions: The mine may face penalties under the Mines and Minerals (Development and Regulation) Amendment Act, 2015, and the Environmental Impact Assessment (EIA) Notification, 2006.
# • Potential charges under different sections: The mine may face charges under various sections of the Mines and Minerals (Development and Regulation) Amendment Act, 2015, and the Environmental Impact Assessment (EIA) Notification, 2006.
# • Liability of specific roles: The mine management, supervisors, and staff may be held liable for non-compliance with environmental regulations.
#
# **CORRECTIVE ACTIONS REQUIRED**
#
# Immediate Actions:
#
# • Renew the expansion clearance (EC) within the next 30 days.
# • Obtain environmental clearance (EC) within the next 60 days.
# • Conduct a thorough review of the mine's environmental management system and implement necessary improvements.
#
# Systemic Improvements:
#
# • Develop and implement a comprehensive environmental management plan.
# • Provide regular training to mine staff on environmental regulations and procedures.
# • Establish a system for monitoring and reporting environmental compliance.
#
# Compliance Verification:
#
# • Conduct regular audits and inspections to ensure compliance with environmental regulations.
# • Maintain accurate records of environmental clearance (EC) and expansion clearance (EC) renewals.
# • Submit regular reports to regulatory authorities.
#
# **PREVENTIVE MEASURES**
#
# • Standard Operating Procedures (SOPs) to implement:
#   • Environmental management plan
#   • Monitoring and reporting system
#   • Training program for mine staff
# • Safety equipment/systems to install:
#   • Environmental monitoring equipment
#   • Waste management system
# • Training programs to conduct:
#   • Environmental awareness training for mine staff
#   • Training on environmental regulations and procedures
# • Monitoring mechanisms to establish:
#   • Regular
# --------------------------------------------------------------------------------
#
#  SOURCES:
# ================================================================================
#
# [1] The Mines and Minerals (Development and Regulation) 1957.pdf
#     Type: Regulation
#     Subject: Mineral Development
#     Year: 1957
#     Chunk: 51/250
#     Preview: . Explanation.—For the removal of doubts, it is hereby clarified that all such Government companies or corporations whose mining lease has been extend...
#
# [2] The Mines and Minerals (Development and Regulation) 1957.pdf
#     Type: Regulation
#     Subject: Mineral Development
#     Year: 1957
#     Chunk: 47/250
#     Preview: . (6) Notwithstanding anything contained in sub-sections (2), (3) and sub-section (4), the period of lease granted before the date of commencement of ...
#
# [3] The Mines and Minerals (Development and Regulation) 1957.pdf
#     Type: Regulation
#     Subject: Mineral Development
#     Year: 1957
#     Chunk: 70/250
#     Preview: . Subs. by Act 38 of 1999, s. 11, for “licence or lease” (w.e.f. 18-12-1999). 2. Ins. by Act 16 of 2021, s. 12 (w.e.f. 28-3-2021). 3. Subs. by Act 16 ...
#
# [4] DGMS_Annual_Report_2014_Eng-08.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 308/383
#     Preview: . 3.0 Safety Issues in mines in unorganized sector 3.1 The States in general may grant mining/quarrying leases of a size not less than ten hectares ea...
#
# [5] The Mines and Minerals (Development and Regulation) 1957.pdf
#     Type: Regulation
#     Subject: Mineral Development
#     Year: 1957
#     Chunk: 87/250
#     Preview: . (13) If the holder of the exploration licence fails to complete the reconnaissance and prospecting operations before expiry of the exploration licen...
#
# ================================================================================
#
#
# ================================================================================
#
#
# ================================================================================
#  QUESTION: Examine this health and safety scenario: A mine employs 240 workers per shift but runs only one first-aid box. No first-aid room exists. What are the regulatory violations?
# ================================================================================
#
#  Searching documents and generating answer...
#
#  ANSWER:
# --------------------------------------------------------------------------------
# **INCIDENT OVERVIEW**
#
# A mine employing 240 workers per shift has only one first-aid box and no first-aid room, violating critical health and safety regulations.
#
# **LEGAL VIOLATIONS IDENTIFIED**
#
# 1. **Regulation**: MMR 1961 - Rule 43
#    **Required**: A suitable first-aid room to be provided and maintained in good order at every mine employing more than 150 persons on any one day of the preceding calendar year.
#    **Violation**: No first-aid room exists.
#    **Risk**: Inadequate first-aid facilities may lead to delayed or inadequate treatment of injured workers, resulting in severe health consequences or even fatalities.
#
# 2. **Regulation**: MMR 1961 - Rule 45
#    **Required**: One first-aid box or cupboard for every 150 workers, equipped with prescribed contents, to be provided and maintained so as to be readily accessible during all working hours.
#    **Violation**: Only one first-aid box is available for 240 workers, which is less than the required number.
#    **Risk**: Inadequate first-aid equipment may lead to delayed or inadequate treatment of injured workers, resulting in severe health consequences or even fatalities.
#
# 3. **Regulation**: MMR 1961 - Rule 44
#    **Required**: First-aid equipment as prescribed in the Third Schedule to be provided and maintained at conveniently accessible stations where injured persons may receive first-aid treatment.
#    **Violation**: No first-aid stations are provided at conveniently accessible locations.
#    **Risk**: Inadequate first-aid facilities may lead to delayed or inadequate treatment of injured workers, resulting in severe health consequences or even fatalities.
#
# **APPLICABLE LEGAL FRAMEWORK**
#
# 1. **Primary Legislation**: Mines Act 1952
#    • Relevant sections: Section 31 (Duty of mine owner to provide safe working conditions), Section 32 (Duty of mine owner to provide medical aid)
#    • Brief descriptions: The Act emphasizes the responsibility of mine owners to provide safe working conditions and medical aid to workers.
#
# 2. **Subordinate Regulations**: MMR 1961
#    • Relevant rules: Rule 43 (First-aid rooms), Rule 44 (First-aid stations), Rule 45 (First-aid appliances)
#    • Specific requirements: The rules specify the requirements for first-aid rooms, stations, and appliances in mines.
#
# 3. **DGMS Circulars/Technical Guidelines**: Not mentioned in the provided context.
#
# **ROOT CAUSE ANALYSIS**
#
# - **Procedural gaps**: The mine's safety protocols and procedures may not be adequate or followed strictly.
# - **Supervisory lapses**: The management or supervisors may not be ensuring compliance with safety regulations.
# - **Communication breakdowns**: There may be a lack of communication between departments or levels of management regarding safety concerns.
# - **Training/competency issues**: The mine's personnel may not be adequately trained or competent in first-aid procedures.
#
# **LEGAL CONSEQUENCES & LIABILITIES**
#
# - **Employer/Management Responsibilities**: The mine owner or management is responsible for ensuring compliance with safety regulations.
# - **Specific penalty provisions**: Fines or imprisonment terms may be applicable under the Mines Act 1952 and MMR 1961.
# - **Potential charges**: Charges may be brought under Sections 31 and 32 of the Mines Act 1952 for failing to provide safe working conditions and medical aid.
# - **Liability of specific roles**: The mine owner, management, supervisors, and personnel may be liable for non-compliance with safety regulations.
#
# **CORRECTIVE ACTIONS REQUIRED**
#
# **Immediate Actions**
#
# - Provide a suitable first-aid room within the next 30 days.
# - Install additional first-aid boxes or cupboards to meet the required ratio of one for every 150 workers.
# - Train personnel in first-aid procedures and ensure they are competent to provide medical aid.
#
# **Systemic Improvements**
#
# - Review and revise the mine's safety protocols and procedures to ensure compliance with regulations.
# - Conduct regular safety audits and inspections to identify and address potential hazards.
# - Provide regular training and awareness programs for personnel on safety and first-aid procedures.
#
# **Compliance Verification**
#
# - Conduct regular audits and inspections to verify compliance with safety regulations.
# - Maintain accurate records of safety protocols, procedures, and training programs.
# - Report any non-compliance or safety incidents to the DGMS.
#
# **PREVENTIVE MEASURES**
#
# - Standard Operating Procedures (SOPs) to implement:
#   • First-aid procedures and protocols.
#   • Safety protocols for handling hazardous materials.
# - Safety equipment/systems to install:
#   • First-aid boxes or cupboards.
#   • Safety signs and warning systems.
# - Training programs to conduct:
#   • First-aid training for personnel.
#   • Safety training for personnel handling hazardous materials.
# - Monitoring mechanisms to establish:
#   • Regular safety audits and inspections.
#   • Incident reporting and investigation procedures.
# --------------------------------------------------------------------------------
#
#  SOURCES:
# ================================================================================
#
# [1] THE MINES RULES 1955.pdf
#     Type: Regulation
#     Subject: General Mining
#     Year: 1955
#     Chunk: 59/147
#     Preview: . John’s Ambulance Association (India). 1[42. First aid personnel - (1) The owner, agent or manager of a mine shall see that every first-aid station p...
#
# [2] THE FACTORIES ACT 1948.pdf
#     Type: Act
#     Subject: General Mining
#     Year: 1948
#     Chunk: 131/274
#     Preview: . 45. First-aid appliances.—(1) There shall in every factory be provided and maintained so as to be readily accessible during all working hours first-...
#
# [3] THE MINES ACT 1952.pdf
#     Type: Act
#     Subject: General Mining
#     Year: 1952
#     Chunk: 58/190
#     Preview: . (5)In every mine wherein more than one hundred and fifty persons are employed, there shall be provided and maintained a first-aid room of such size ...
#
# [4] THE MINES RULES 1955.pdf
#     Type: Regulation
#     Subject: General Mining
#     Year: 1955
#     Chunk: 60/147
#     Preview: . 2[First-aid] rooms (1) At every mine employing more than 150 persons on any one day of the preceding calendar year, there shall be provided and main...
#
# [5] THE MINES RULES 1955.pdf
#     Type: Regulation
#     Subject: General Mining
#     Year: 1955
#     Chunk: 63/147
#     Preview: . 1[44. First aid stations.-(1) At every mine there shall be provided and maintained first-aid equipment as prescribed in the Third Schedule, at conve...
#
# ================================================================================
#
#
# ================================================================================
#
#
# ================================================================================
#  QUESTION: Analyze this environmental violation: A mine temporarily diverts a natural seasonal stream to develop a haul road without forest/water authority approval. What laws are being breached?
# ================================================================================
#
#  Searching documents and generating answer...
#
#  ANSWER:
# --------------------------------------------------------------------------------
# **INCIDENT OVERVIEW**
#
# A mine temporarily diverts a natural seasonal stream to develop a haul road without forest/water authority approval, posing a risk to environmental safety and potentially violating relevant regulations.
#
# **LEGAL VIOLATIONS IDENTIFIED**
#
# • Regulation 121(1) - Working near mine boundaries - The owner, agent, or manager of every belowground mine shall have fixed boundaries of the mine. Notwithstanding anything contained in sub-regulation (2), these shall not be changed except with the express permission of the Chief Inspector in writing and subject to such conditions as he may specify therein.
#   Required: Obtain permission from the Chief Inspector before making any changes to the mine boundaries.
#   Violation: The mine diverted a seasonal stream without approval, changing the mine boundaries.
#   Risk: Environmental damage, potential collapse of the mine, and harm to nearby communities.
#
# • Regulation 121(2) - Working near mine boundaries - Without prejudice to the provisions contained in sub-section (1), the Chief Inspector or the Inspector, as the case may be, may, by order in writing addressed to the owner, agent or manager of a mine, prohibit the extraction or reduction of pillars or blocks of minerals in any mine or part thereof, if, in his opinion, such operation is likely to cause the crushing of pillars or blocks of minerals or the premature collapse of any part of the workings or otherwise endanger the mine or the life or safety of persons employed therein or if, in his opinion, adequate provision against the outbreak of fire or flooding has not been made by providing for the sealing off and isolation of the part of the mine in which such operation is contemplated and for restricting the area that might be affected by fire or flooding.
#   Required: Obtain permission from the Chief Inspector before making any changes to the mine boundaries.
#   Violation: The mine diverted a seasonal stream without approval, potentially endangering the mine and nearby communities.
#   Risk: Environmental damage, potential collapse of the mine, and harm to nearby communities.
#
# **APPLICABLE LEGAL FRAMEWORK**
#
# 1. Primary Legislation (Mines Act 1952)
#    • Section 18(4) - The owner, agent, or manager of every mine shall take all necessary measures to prevent accidents and ensure the safety of persons employed in the mine.
#    • Section 18(4) - The owner, agent, or manager of every mine shall take all necessary measures to prevent accidents and ensure the safety of persons employed in the mine.
#
# 2. Subordinate Regulations (Metalliferous Mines Regulations, 1961)
#    • Regulation 181 - The owner, agent, or manager of every mine shall ensure that all persons employed in the mine are properly trained and equipped to perform their duties safely.
#    • Regulation 40(1) - The owner, agent, or manager of every mine shall ensure that all persons employed in the mine are properly supervised and monitored to prevent accidents.
#
# 3. DGMS Circulars/Technical Guidelines
#    • None mentioned in the provided context.
#
# **ROOT CAUSE ANALYSIS**
#
# - Procedural gaps: The mine failed to obtain approval from the forest/water authority before diverting the seasonal stream.
# - Supervisory lapses: The mine management failed to ensure compliance with relevant regulations and guidelines.
# - Communication breakdowns: The mine failed to communicate with the forest/water authority and obtain necessary approvals.
# - Training/competency issues: The mine management and employees may not have received adequate training on environmental safety and regulations.
#
# **LEGAL CONSEQUENCES & LIABILITIES**
#
# - Employer/Management Responsibilities under the law: The mine owner, agent, or manager is responsible for ensuring compliance with relevant regulations and guidelines.
# - Specific penalty provisions: Fines and imprisonment terms may be applicable under the Mines Act 1952 and the Metalliferous Mines Regulations, 1961.
# - Potential charges under different sections: The mine owner, agent, or manager may face charges under sections 18(4) of the Mines Act 1952 and Regulation 181 of the Metalliferous Mines Regulations, 1961.
# - Liability of specific roles: The mine management, including the owner, agent, or manager, may be held liable for the environmental damage and potential collapse of the mine.
#
# **CORRECTIVE ACTIONS REQUIRED**
#
# Immediate Actions:
#
# - Obtain approval from the forest/water authority for the diversion of the seasonal stream.
# - Restore the seasonal stream to its original course.
# - Conduct a thorough environmental impact assessment to identify potential risks and develop mitigation strategies.
#
# Systemic Improvements:
#
# - Develop and implement a comprehensive environmental management plan to ensure compliance with relevant regulations and guidelines.
# - Provide regular training and awareness programs for mine employees on environmental safety and regulations.
# - Establish a system for monitoring and reporting environmental incidents and near-misses.
#
# Compliance Verification:
#
# - Conduct regular audits and inspections to ensure compliance with relevant regulations and guidelines.
# - Maintain accurate records of environmental incidents and near-misses.
# - Submit regular reports to the forest/water authority and the DGMS.
#
# **PREVENTIVE MEASURES**
#
# - Develop and implement Standard
# --------------------------------------------------------------------------------
#
#  SOURCES:
# ================================================================================
#
# [1] COAL MINES REGULATION 2017.pdf
#     Type: Regulation
#     Subject: Coal Mining
#     Year: 2017
#     Chunk: 340/639
#     Preview: . (2) If the owner fails to construct such protective works within the time specified in the order referred to in sub-regulation (1), the Chief Inspec...
#
# [2] THE MINES ACT 1952.pdf
#     Type: Act
#     Subject: General Mining
#     Year: 1952
#     Chunk: 61/190
#     Preview: . (2)Without prejudice to the provisions contained in sub-section (1), the Chief Inspector or the Inspector, as the case may be, may, by order in writ...
#
# [3] COAL MINES REGULATION 2017.pdf
#     Type: Regulation
#     Subject: Coal Mining
#     Year: 2017
#     Chunk: 452/639
#     Preview: . (6) No working shall be made in any mine vertically below- (a) any part of any river, canal, lake, tank or other surface reservoir; or (b) any spot ...
#
# [4] THE METALLIFEROUS MINES REGULATIONS 1961.pdf
#     Type: Regulation
#     Subject: General Mining
#     Year: 1961
#     Chunk: 296/528
#     Preview: . (2) If the owner fails to construct such protective works within the time specified in the order, the Chief Inspector may get the works executed by ...
#
# [5] SANKET NON-COAL MINES 2016-22.pdf
#     Type: Document
#     Subject: Coal Mining
#     Year: 2016
#     Chunk: 754/1096
#     Preview: presence through the designated road as directed by him and provided for the proper discipline of the operator and the supervisor/competent person as ...
#
# ================================================================================
#
#
# ================================================================================
#
#
# ================================================================================
#  QUESTION: Evaluate this storage compliance issue: A mine stores 6,000 litres of diesel in barrels near workshop without PESO license. Identify the legal violations and applicable acts.
# ================================================================================
#
#  Searching documents and generating answer...
#
#  ANSWER:
# --------------------------------------------------------------------------------
# **INCIDENT OVERVIEW**
#
# A mine stores 6,000 litres of diesel in barrels near the workshop without a PESO license, posing a significant risk to safety and environmental pollution.
#
# **LEGAL VIOLATIONS IDENTIFIED**
#
# 1. **Storage of Diesel without License**
#    - Regulation: PESO Act 1976 - Section 3: License for Storage of Hazardous Substances
#    - Required: Obtain a license from the Petroleum and Explosives Safety Organisation (PESO) for storing hazardous substances like diesel.
#    - Violation: Diesel is stored without a PESO license.
#    - Risk: Unauthorised storage of hazardous substances poses a risk to safety and environmental pollution.
#
# 2. **Non-Compliance with Storage Regulations**
#    - Regulation: Mines Rules 1961 - Rule 94: Storage and Use of Flammable Material
#    - Required: Store flammable materials like diesel at least 30 meters away from any oil well or workshop.
#    - Violation: Diesel is stored near the workshop without maintaining the required distance.
#    - Risk: Proximity to the workshop increases the risk of fire and explosion.
#
# 3. **Non-Compliance with Environmental Regulations**
#    - Regulation: Environment (Protection) Rules, 1986 - Rule 5: Standards and Guidelines for Discharging Liquid Effluent and Gaseous Emission
#    - Required: Comply with the standards and guidelines for discharging liquid effluent and gaseous emission.
#    - Violation: Diesel storage without a PESO license may lead to unauthorised discharge of hazardous substances.
#    - Risk: Environmental pollution and harm to human health.
#
# **APPLICABLE LEGAL FRAMEWORK**
#
# 1. **Primary Legislation**
#    - Mines Act 1952 - Section 21: Power to make rules
#    - Mines Rules 1961 - Rule 94: Storage and Use of Flammable Material
#    - Environment (Protection) Act 1986 - Section 6: Power to make rules
#
# 2. **Subordinate Regulations**
#    - PESO Act 1976 - Section 3: License for Storage of Hazardous Substances
#    - Environment (Protection) Rules, 1986 - Rule 5: Standards and Guidelines for Discharging Liquid Effluent and Gaseous Emission
#
# 3. **DGMS Circulars/Technical Guidelines**
#    - DGMS Circular 27 of 2017: Guidelines for Storage of Hazardous Substances
#
# **ROOT CAUSE ANALYSIS**
#
# - Procedural gaps: Lack of proper documentation and record-keeping for diesel storage.
# - Supervisory lapses: Inadequate supervision and monitoring of storage facilities.
# - Communication breakdowns: Failure to communicate with PESO for obtaining a license.
# - Training/competency issues: Insufficient training on storage regulations and environmental guidelines.
#
# **LEGAL CONSEQUENCES & LIABILITIES**
#
# - Employer/Management Responsibilities under the law: The mine owner and management are liable for non-compliance with storage regulations and environmental guidelines.
# - Specific penalty provisions: Fines and imprisonment terms under the PESO Act 1976 and Environment (Protection) Act 1986.
# - Potential charges under different sections: Charges under the Mines Act 1952, PESO Act 1976, and Environment (Protection) Act 1986.
# - Liability of specific roles: The mine manager and supervisor are liable for non-compliance with storage regulations and environmental guidelines.
#
# **CORRECTIVE ACTIONS REQUIRED**
#
# Immediate Actions:
#
# - Obtain a PESO license for storing diesel within 30 days.
# - Relocate the diesel storage facility at least 30 meters away from the workshop.
#
# Systemic Improvements:
#
# - Develop and implement Standard Operating Procedures (SOPs) for storage and handling of hazardous substances.
# - Conduct regular training sessions for employees on storage regulations and environmental guidelines.
# ...
# - **Compliance Verification**:
#   - Conduct regular audits and inspections to ensure compliance with safety regulations.
#   - Maintain accurate records of compliance and non-compliance.
#
# **PREVENTIVE MEASURES**
#
# - **Standard Operating Procedures (SOPs)**: Develop and implement SOPs for entering unsupported areas.
# - **Safety equipment/systems**: Install safety equipment and systems to prevent accidents in unsupported areas.
# - **Training programs**: Conduct regular training programs for miners on safety protocols and regulations.
# - **Monitoring mechanisms**: Establish monitoring mechanisms to ensure compliance with safety regulations.
# --------------------------------------------------------------------------------
#
#  SOURCES:
# ================================================================================
#
# [1] SANKET COAL MINES 2016-22.pdf
#     Type: Document
#     Subject: Coal Mining
#     Year: 2016
#     Chunk: 10/984
#     Preview: . INTRODUCTION Mining has been a hazardous occupation. The history of mine accidents is a tragic and sobering reminder of the inherent risks associate...
#
# [2] SANKET NON-COAL MINES 2016-22.pdf
#     Type: Document
#     Subject: Coal Mining
#     Year: 2016
#     Chunk: 11/1096
#     Preview: . Factors such as human error, inadequate safety protocols, inadequate training, and unforeseen geological conditions can still lead to accidents. Add...
#
# [3] DGMS_Annual_Report_2014_Eng-09.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 326/669
#     Preview: . General Safety in Mines Safety in Mines :- Duty of care; occupational hazards of mining; causes and prevention; accidents and their classification; ...
#
# [4] DGMS_Annual_Report_2014_Eng-09.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 366/669
#     Preview: . General Safety in Mines Safety in Mines :- Duty of care; occupational hazards of mining; causes and prevention; accidents and their classification; ...
#
# [5] DGMS_Annual_Report_2014_Eng-09.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 593/669
#     Preview: . General Safety in Mines Safety in Mines :- Duty of care; occupational hazards of mining; causes and prevention; accidents and their classification; ...
#
# ================================================================================
#
#
# ================================================================================
#
#
# ================================================================================
#  QUESTION: Review this occupational health matter: Operators using DTH drill machines are not provided ear protection even though noise level is 106 dB. What are the legal violations?
# ================================================================================
#
#  Searching documents and generating answer...
#
#  ANSWER:
# --------------------------------------------------------------------------------
# **INCIDENT OVERVIEW**
#
# Operators using DTH drill machines are not provided ear protection even though the noise level is 106 dB, posing a significant risk to their hearing health.
#
# **LEGAL VIOLATIONS IDENTIFIED**
#
# 1. **Regulation**: 124. Protection against noise. - (2) No person shall be allowed to work without appropriate ear protection in an area if he is exposed to an equivalent continuous noise level exceeding 90 dB(A).
#    **Required**: Ear protection for workers exposed to noise levels above 90 dB(A).
#    **Violation**: Operators using DTH drill machines are not provided ear protection despite noise levels exceeding 90 dB(A).
#    **Risk**: Hearing loss and potential long-term health consequences.
#
# 2. **Regulation**: 124. Protection against noise. - (3) No person shall enter or be allowed to enter an area in which the sound level is 140 dB(A) or more.
#    **Required**: Restrict access to areas with sound levels above 140 dB(A) without proper ear protection.
#    **Violation**: Operators are exposed to noise levels exceeding 140 dB(A) without proper protection.
#    **Risk**: Severe hearing loss and potential long-term health consequences.
#
# 3. **Regulation**: 106 THE GAZETTE OF INDIA : EXTRAORDINARY [PART II—SEC. 3(i)] (3) Every person provided with protective equipment shall use the same while at work.
#    **Required**: Workers must use provided protective equipment while working.
#    **Violation**: Operators are not using provided ear protection while working.
#    **Risk**: Hearing loss and potential long-term health consequences.
#
# **APPLICABLE LEGAL FRAMEWORK**
#
# 1. **Primary Legislation**: Mines Act 1952
#    • Relevant sections: 124 (Protection against noise), 106 (Protective equipment)
#    • Brief descriptions: The Act mandates protection against noise and requires the use of protective equipment.
#
# 2. **Subordinate Regulations**: MMR 1961, CMR 2017 (not specified in provided context)
#    • Relevant rules: Not specified in the provided context.
#
# 3. **DGMS Circulars/Technical Guidelines**: DGMS (Tech) Circular No.18 of 1975 (Protection of workers against Noise & Vibration in Working Environment.)
#    • Relevant circular: Mandates audiometry as a part of mandatory medical examination for workers exposed to noise levels above 90 dB(A).
#
# **ROOT CAUSE ANALYSIS**
#
# - **Procedural gaps**: Lack of implementation of noise protection measures and audiometry for workers exposed to high noise levels.
# - **Supervisory lapses**: Inadequate supervision and enforcement of safety regulations.
# - **Communication breakdowns**: Insufficient communication about the risks of noise exposure and the importance of using ear protection.
# - **Training/competency issues**: Inadequate training on safety procedures and the use of protective equipment.
#
# **LEGAL CONSEQUENCES & LIABILITIES**
#
# - **Employer/Management Responsibilities**: Under the Mines Act 1952, employers are responsible for providing a safe working environment and ensuring compliance with safety regulations.
# - **Specific penalty provisions**: Fines and imprisonment terms may be applicable under the Mines Act 1952 for non-compliance with safety regulations.
# - **Potential charges**: Charges may be brought under sections 124 and 106 of the Mines Act 1952 for non-compliance with noise protection regulations.
# - **Liability of specific roles**: Managers, supervisors, and blasters may be held liable for non-compliance with safety regulations.
#
# **CORRECTIVE ACTIONS REQUIRED**
#
# **Immediate Actions**
#
# - Provide ear protection to operators using DTH drill machines.
# - Conduct audiometry tests for workers exposed to high noise levels.
# - Implement noise protection measures to reduce noise levels below 90 dB(A).
#
# **Systemic Improvements**
#
# - Develop and implement Standard Operating Procedures (SOPs) for noise protection and audiometry.
# - Provide regular training on safety procedures and the use of protective equipment.
# - Conduct regular inspections to ensure compliance with safety regulations.
#
# **Compliance Verification**
#
# - Conduct regular audits to ensure compliance with safety regulations.
# - Maintain documentation of audiometry tests and noise protection measures.
# - Report non-compliance to DGMS.
#
# **PREVENTIVE MEASURES**
#
# - Install noise-reducing equipment in DTH drill machines.
# - Develop and implement SOPs for noise protection and audiometry.
# - Conduct regular training on safety procedures and the use of protective equipment.
# - Establish a monitoring system to track noise levels and ensure compliance with safety regulations.
# --------------------------------------------------------------------------------
#
#  SOURCES:
# ================================================================================
#
# [1] The_oil_mines_regulation_2017.pdf
#     Type: Regulation
#     Subject: General Mining
#     Year: 2017
#     Chunk: 225/262
#     Preview: . (2)The owner, agent and manager of a mine shall ensure supply of the protective equipment under sub- regulation (1) free of charge. 106 THE GAZETTE ...
#
# [2] DGMS_Annual_Report_2014_Eng-13.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 634/1512
#     Preview: . The conference recommends that the States may grant mining leases in conformity of Central Laws. 1.9.5 DGMS should organize Orientation Programmes f...
#
# [3] DGMS_Annual_Report_2014_Eng-13.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 1392/1512
#     Preview: . The conference recommends that the States may grant mining leases in conformity of Central Laws. 1.9.5 DGMS should organize Orientation Programmes f...
#
# [4] DGMS_Annual_Report_2014_Eng-08.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 310/383
#     Preview: . The conference recommends that the States may grant mining leases in conformity of Central Laws. 3.6 DGMS should organize Orientation Programmes for...
#
# [5] DGMS_Annual_Report_2014_Eng-08.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 295/383
#     Preview: . The instrument should be developed by a S&T project which should be guided by a committee consisting of an officer from DGMS and others from Coal In...
#
# ================================================================================
#
#
# ================================================================================
#
#
# ================================================================================
#  QUESTION: Examine this dumping safety violation: Material is being dumped over the edge without maintaining the 10m safety barrier from dump edge. What rules and regulations are being violated?
# ================================================================================
#
#  Searching documents and generating answer...
#
#  ANSWER:
# --------------------------------------------------------------------------------
# **INCIDENT OVERVIEW**
#
# Material is being dumped over the edge without maintaining the 10m safety barrier from dump edge, posing a significant risk to the safety of personnel and equipment.
#
# **LEGAL VIOLATIONS IDENTIFIED**
#
# 1. **Regulation 11.1(b) of Directorates's letter No.** - **Provision of Stop Blocks or Berm**
#    Required: Sufficient stop blocks to be provided at the tipping point and used on every occasion OB was dumped from the dumper, or a proper berm of adequate width and of a height not less than half the diameter of the dumper-wheels (and in any case not less than 1.0 meters in height) to be provided at the edge of the dump.
#    Violation: Material is being dumped over the edge without maintaining the required safety barrier.
#    Risk: ⚠️ WARNING - Significant risk to the safety of personnel and equipment.
#
# 2. **Regulation 40 (4) (a) read with Regulation 239 of the Coal Mine Regulation, 2017** - **Prohibition on Overcrowding and Proximity of Machinery**
#    Required: The tipper not to be placed in close proximity of the other tipper for dumping overburden at dump yard.
#    Violation: Material is being dumped over the edge, potentially causing overcrowding and proximity issues.
#    Risk: ⚠️ WARNING - Risk of accidents and injuries due to overcrowding and proximity of machinery.
#
# 3. **Regulation 128(7) read with provision at Sl. no.- (7) of Codes of practice for safe dumping of OB at dump yard by dumpers and tippers framed under the provisions of Regulation 110 of the Coal Mine Regulation, 2017** - **Prohibition on Restricted Narrow Places**
#    Required: The restricted narrow Place at dump yard to be kept securely fenced or blocked with strong parapet wall of adequate height and width demarcated with red flag.
#    Violation: Material is being dumped over the edge, potentially creating a restricted narrow place.
#    Risk: ⚠️ WARNING - Risk of accidents and injuries due to restricted narrow places.
#
# **APPLICABLE LEGAL FRAMEWORK**
#
# 1. **Primary Legislation (Mines Act 1952)**
#    • Section 72(h) - Prohibition on overcrowding of machinery
#    • Section 72(h) read with Regulation 45(2) & 45(3) of the Coal Mines Regulations, 2017 - Prohibition on overcrowding of machinery
#
# 2. **Subordinate Regulations (Coal Mines Regulations, 2017)**
#    • Regulation 40 (4) (a) - Prohibition on overcrowding and proximity of machinery
#    • Regulation 47(6)(e) read with Regulation 239 - Prohibition on overcrowding at the dump yard
#    • Regulation 63(d) - Prohibition on overtaking of dumpers
#    • Regulation 110 - Prohibition on unsafe dumping practices
#    • Regulation 128(7) - Prohibition on restricted narrow places
#
# 3. **DGMS Circulars/Technical Guidelines**
#    • Codes of practice for safe dumping of OB at dump yard by dumpers and tippers framed under the provisions of Regulation 110 of the Coal Mine Regulation, 2017 - Provision of stop blocks or berm
#
# **ROOT CAUSE ANALYSIS**
#
# * Procedural gaps: Insufficient training and supervision of personnel involved in dumping operations.
# * Supervisory lapses: Failure of supervisors to ensure compliance with safety regulations and guidelines.
# * Communication breakdowns: Lack of clear communication between personnel involved in dumping operations.
# * Training/competency issues: Insufficient training and competency of personnel involved in dumping operations.
#
# **LEGAL CONSEQUENCES & LIABILITIES**
#
# * Employer/Management Responsibilities under the law: Employers and management are responsible for ensuring compliance with safety regulations and guidelines.
# * Specific penalty provisions: Fines and imprisonment terms may be imposed under the Mines Act 1952 and Coal Mines Regulations, 2017.
# * Potential charges under different sections: Charges may be brought under sections 72(h), 40 (4) (a), 47(6)(e), 63(d), 110, and 128(7) of the Coal Mines Regulations, 2017.
# * Liability of specific roles: Managers, supervisors, and personnel involved in dumping operations may be held liable for non-compliance with safety regulations and guidelines.
#
# **CORRECTIVE ACTIONS REQUIRED**
#
# Immediate Actions:
#
# * Ensure that sufficient stop blocks are provided at the tipping point and used on every occasion OB is dumped from the dumper.
# * Ensure that a proper berm of adequate width and of a height not less than half the diameter of the dumper-wheels (and in any case not less than 1.0 meters in height) is provided at the edge of the dump.
# * Ensure that the tipper is not placed in close proximity of the other tipper for dumping overburden at dump yard.
# * Ensure
# --------------------------------------------------------------------------------
#
#  SOURCES:
# ================================================================================
#
# [1] SANKET NON-COAL MINES 2016-22.pdf
#     Type: Document
#     Subject: Coal Mining
#     Year: 2016
#     Chunk: 279/1096
#     Preview: . The dumper operator, who was not wearing the seat-belt, was thrown out of the cabin to receive serious head injuries to which he succumbed. Had, i) ...
#
# [2] SANKET COAL MINES 2016-22.pdf
#     Type: Document
#     Subject: Coal Mining
#     Year: 2016
#     Chunk: 796/984
#     Preview: . no. 1 of Codes of practice for safe dumping of OB at dump yard by dumpers and tippers framed under the provisions of Regulation 110 of the Coal Mine...
#
# [3] DGMS_Annual_Report_2014_Eng-13.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 1203/1512
#     Preview: . Improper drainage around the dump. viii. Presence of Black Cotton Soil at the base of dump ix. Presence of fault plane in case of internal dumping x...
#
# [4] DGMS_Annual_Report_2014_Eng-14.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 236/375
#     Preview: . The dumping was made in two lifts. Overall height of the dump was about 664m and the width between the lifts was not sufficient; 3. The ground water...
#
# [5] SANKET COAL MINES 2016-22.pdf
#     Type: Document
#     Subject: Coal Mining
#     Year: 2016
#     Chunk: 540/984
#     Preview: . Had, 167 i) the Assistant Manager inspected and examined the working/dump yard under his charge and accordingly fixed the optimum number of dumpers ...
#
# ================================================================================
#
#
# ================================================================================

# %%
# ============================================================================
# CELL 8: Statistics & Save Results
# ============================================================================
print("\n" + "="*80)
print(" SESSION STATISTICS")
print("="*80)

stats = rag_system.get_statistics()
for key, value in stats.items():
    print(f"{key}: {value}")

print("="*80 + "\n")

# Save query log
rag_system.save_query_log()

print(f" Completed: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
# Out:
# ================================================================================
#  SESSION STATISTICS
# ================================================================================
# total_queries: 10
# successful: 10
# failed: 0
# success_rate: 100.0%
# ================================================================================
#
#  Query log saved to: /kaggle/working/queries_log.json
#  Completed: 2025-11-14 19:16:53

# %%
# ============================================================================
# CELL 9: Interactive Query (Optional)
# ============================================================================



# Ask your own question
my_question = "What are the penalties for violating mining safety regulations?"

result = rag_system.query(my_question, show_sources=True)

# Access the answer
print("\nYour Answer:")
print(result['answer'])
# Out:
# ================================================================================
#  QUESTION: What are the penalties for violating mining safety regulations?
# ================================================================================
#
#  Searching documents and generating answer...
#
#  ANSWER:
# --------------------------------------------------------------------------------
# **INCIDENT OVERVIEW**
#
# A mining accident occurred due to non-compliance with safety regulations, resulting in potential harm to mine workers. The incident highlights the importance of adhering to safety protocols to prevent accidents.
#
# **LEGAL VIOLATIONS IDENTIFIED**
#
# • **Mines Act 1952** - **Section 21**: The mine management failed to ensure that all operations in the mine were done in accordance with the provisions of the Mines Act and Regulations, Rules, bye-laws and orders made there under.
#   Required: Compliance with safety regulations
#   Violation: Failure to ensure compliance
#   Risk: Potential harm to mine workers
#
# • **Metalliferous Mines Regulations, 1961** - **Regulation 116**: The mine management failed to exercise personal supervision to ensure that all operations in the mine were done in accordance with the provisions of the Mines Act and Regulations, Rules, bye-laws and orders made there under.
#   Required: Personal supervision to ensure compliance
#   Violation: Failure to exercise personal supervision
#   Risk: Potential harm to mine workers
#
# **APPLICABLE LEGAL FRAMEWORK**
#
# 1. **Primary Legislation**:
#    • **Mines Act 1952**:
#      - **Section 21**: Compliance with safety regulations
#      - **Section 22**: Responsibility of mine owners and managers
#    • **Mines Rules, 1955**:
#      - **Rule 7**: Safety measures for mines
#
# 2. **Subordinate Regulations**:
#    • **Metalliferous Mines Regulations, 1961**:
#      - **Regulation 116**: Personal supervision to ensure compliance
#      - **Regulation 117**: Safety measures for mines
#
# 3. **DGMS Circulars/Technical Guidelines**:
#    • **DGMS Circular No. 1 of 2018**: Safety guidelines for mines
#
# **ROOT CAUSE ANALYSIS**
#
# - **Procedural gaps**: Failure to establish and follow safety protocols
# - **Supervisory lapses**: Failure of mine management to exercise personal supervision
# - **Communication breakdowns**: Failure to inform mine workers of safety protocols
# - **Training/competency issues**: Lack of training on safety protocols for mine workers
#
# **LEGAL CONSEQUENCES & LIABILITIES**
#
# - **Employer/Management Responsibilities**: Under the Mines Act 1952, mine owners and managers are responsible for ensuring compliance with safety regulations.
# - **Penalty provisions**: Under the Mines Act 1952, individuals found guilty of violating safety regulations may face imprisonment for a term which may extend to two years, or with the minimum fine of one lakh rupees per day and in the case of continuing failure, with a maximum fine of two lakh rupees for every day during which the failure continues.
# - **Liability of specific roles**: Mine managers and supervisors may face liability for failing to exercise personal supervision and ensure compliance with safety regulations.
#
# **CORRECTIVE ACTIONS REQUIRED**
#
# - **Immediate Actions**:
#   • Conduct a thorough investigation into the incident
#   • Implement safety protocols to prevent similar incidents
#   • Provide training to mine workers on safety protocols
# - **Systemic Improvements**:
#   • Establish a safety committee to oversee safety protocols
#   • Conduct regular safety audits and inspections
#   • Implement a system for reporting safety incidents
# - **Compliance Verification**:
#   • Conduct regular audits to ensure compliance with safety regulations
#   • Maintain documentation of safety protocols and training
#   • Report safety incidents to the DGMS
#
# **PREVENTIVE MEASURES**
#
# - **Standard Operating Procedures (SOPs)**: Establish and implement SOPs for safety protocols
# - **Safety equipment/systems**: Install safety equipment and systems to prevent accidents
# - **Training programs**: Conduct regular training programs for mine workers on safety protocols
# - **Monitoring mechanisms**: Establish monitoring mechanisms to ensure compliance with safety regulations
# --------------------------------------------------------------------------------
#
#  SOURCES:
# ================================================================================
#
# [1] SANKET NON-COAL MINES 2016-22.pdf
#     Type: Document
#     Subject: Coal Mining
#     Year: 2016
#     Chunk: 567/1096
#     Preview: to excercise personal supervision and ensure that all operations in the mine were done in accordance with the provisions of the Mines Act and Regulati...
#
# [2] THE COAL MINES (SPECIAL PROVISIONS) ACT 2015.pdf
#     Type: Act
#     Subject: Coal Mining
#     Year: 2015
#     Chunk: 59/109
#     Preview: . 23. Penalties for certain offences.––If any person— (a) obstructs or causes any impediment in taking possession or in the management and operation o...
#
# [3] DGMS_Annual_Report_2014_Eng-13.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 1134/1512
#     Preview: . A few accidents involving serious bodily injury and most of the important dangerous occurrences are also investigated by DGMS Officers. Arising out ...
#
# [4] DGMS_Annual_Report_2014_Eng-09.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 13/669
#     Preview: . A few accidents involving serious bodily injury and most of the important dangerous occurrences are also investigated by DGMS Officers. Arising out ...
#
# [5] DGMS_Annual_Report_2014_Eng-12.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 11/205
#     Preview: . A few accidents involving serious bodily injury and most of the important dangerous occurrences are also investigated by DGMS Officers. Arising out ...
#
# ================================================================================
#
#
# Your Answer:
# **INCIDENT OVERVIEW**
#
# A mining accident occurred due to non-compliance with safety regulations, resulting in potential harm to mine workers. The incident highlights the importance of adhering to safety protocols to prevent accidents.
#
# **LEGAL VIOLATIONS IDENTIFIED**
#
# • **Mines Act 1952** - **Section 21**: The mine management failed to ensure that all operations in the mine were done in accordance with the provisions of the Mines Act and Regulations, Rules, bye-laws and orders made there under.
#   Required: Compliance with safety regulations
#   Violation: Failure to ensure compliance
#   Risk: Potential harm to mine workers
#
# • **Metalliferous Mines Regulations, 1961** - **Regulation 116**: The mine management failed to exercise personal supervision to ensure that all operations in the mine were done in accordance with the provisions of the Mines Act and Regulations, Rules, bye-laws and orders made there under.
#   Required: Personal supervision to ensure compliance
#   Violation: Failure to exercise personal supervision
#   Risk: Potential harm to mine workers
#
# **APPLICABLE LEGAL FRAMEWORK**
#
# 1. **Primary Legislation**:
#    • **Mines Act 1952**:
#      - **Section 21**: Compliance with safety regulations
#      - **Section 22**: Responsibility of mine owners and managers
#    • **Mines Rules, 1955**:
#      - **Rule 7**: Safety measures for mines
#
# 2. **Subordinate Regulations**:
#    • **Metalliferous Mines Regulations, 1961**:
#      - **Regulation 116**: Personal supervision to ensure compliance
#      - **Regulation 117**: Safety measures for mines
#
# 3. **DGMS Circulars/Technical Guidelines**:
#    • **DGMS Circular No. 1 of 2018**: Safety guidelines for mines
#
# **ROOT CAUSE ANALYSIS**
#
# - **Procedural gaps**: Failure to establish and follow safety protocols
# - **Supervisory lapses**: Failure of mine management to exercise personal supervision
# - **Communication breakdowns**: Failure to inform mine workers of safety protocols
# - **Training/competency issues**: Lack of training on safety protocols for mine workers
#
# **LEGAL CONSEQUENCES & LIABILITIES**
#
# - **Employer/Management Responsibilities**: Under the Mines Act 1952, mine owners and managers are responsible for ensuring compliance with safety regulations.
# - **Penalty provisions**: Under the Mines Act 1952, individuals found guilty of violating safety regulations may face imprisonment for a term which may extend to two years, or with the minimum fine of one lakh rupees per day and in the case of continuing failure, with a maximum fine of two lakh rupees for every day during which the failure continues.
# - **Liability of specific roles**: Mine managers and supervisors may face liability for failing to exercise personal supervision and ensure compliance with safety regulations.
#
# **CORRECTIVE ACTIONS REQUIRED**
#
# - **Immediate Actions**:
#   • Conduct a thorough investigation into the incident
#   • Implement safety protocols to prevent similar incidents
#   • Provide training to mine workers on safety protocols
# - **Systemic Improvements**:
#   • Establish a safety committee to oversee safety protocols
#   • Conduct regular safety audits and inspections
#   • Implement a system for reporting safety incidents
# - **Compliance Verification**:
#   • Conduct regular audits to ensure compliance with safety regulations
#   • Maintain documentation of safety protocols and training
#   • Report safety incidents to the DGMS
#
# **PREVENTIVE MEASURES**
#
# - **Standard Operating Procedures (SOPs)**: Establish and implement SOPs for safety protocols
# - **Safety equipment/systems**: Install safety equipment and systems to prevent accidents
# - **Training programs**: Conduct regular training programs for mine workers on safety protocols
# - **Monitoring mechanisms**: Establish monitoring mechanisms to ensure compliance with safety regulations

# %%
# ============================================================================
# CELL 10: Batch Query Function (Optional)
# ============================================================================


def batch_query(questions_list):
    """
    Query multiple questions at once
    
    Usage:
        my_questions = [
            "Question 1?",
            "Question 2?",
            "Question 3?"
        ]
        batch_results = batch_query(my_questions)
    """
    print(f"\n Running batch queries ({len(questions_list)} questions)...\n")
    
    batch_results = []
    for i, question in enumerate(questions_list, 1):
        print(f"\n{'='*80}")
        print(f"Query {i}/{len(questions_list)}")
        print(f"{'='*80}")
        
        result = rag_system.query(question, show_sources=True)
        batch_results.append(result)
    
    return batch_results

# Example usage :

custom_questions = [
    "What are the environmental regulations for mining?",
    "What are the requirements for mine closure?",
    "What are the provisions for compensation in case of mining accidents?"
]

batch_results = batch_query(custom_questions)
# Out:
#  Running batch queries (3 questions)...
#
#
# ================================================================================
# Query 1/3
# ================================================================================
#
# ================================================================================
#  QUESTION: What are the environmental regulations for mining?
# ================================================================================
#
#  Searching documents and generating answer...
#
#  ANSWER:
# --------------------------------------------------------------------------------
# **ENVIRONMENTAL REGULATIONS FOR MINING**
#
# **DIRECT ANSWER**
#
# The environmental regulations for mining in India are governed by various laws and regulations, including the Mines Act, 1952, and the Coal Mines (Conservation and Development) Rules, 1975. These regulations focus on environmental management, mine closure planning, rehabilitation and resettlement, and health and safety standards.
#
# **LEGAL BASIS**
#
# * The Mines Act, 1952 - Section 5: Requires mine owners to take measures for the prevention of accidents and the protection of the health and safety of workers.
# * The Coal Mines (Conservation and Development) Rules, 1975 - Rule 12(1)(ii)(d): Regulates the construction of dams, and Rule 12(1)(ii)(e): Regulates artificial barriers.
# * The Coal Mines (Conservation and Development) Rules, 1975 - Rule 12(2)(ii): Requires improvements in exploration and drilling techniques.
#
# **DETAILED EXPLANATION**
#
# The Mines Act, 1952, is the primary legislation governing mining in India. It requires mine owners to take measures for the prevention of accidents and the protection of the health and safety of workers. The Coal Mines (Conservation and Development) Rules, 1975, provide specific regulations for coal mining, including environmental management and health and safety standards.
#
# **COMPLIANCE REQUIREMENTS**
#
# * Mine owners must take measures for the prevention of accidents and the protection of the health and safety of workers.
# * Mine owners must comply with the Coal Mines (Conservation and Development) Rules, 1975, including regulations on environmental management, health and safety standards, and rehabilitation and resettlement.
# * Mine owners must maintain records and submit reports to the DGMS as required by law.
#
# **PRACTICAL GUIDANCE**
#
# 1. Conduct regular environmental impact assessments to identify potential risks and develop strategies for mitigation.
# 2. Implement measures to prevent accidents, including regular safety inspections and training for workers.
# 3. Comply with regulations on rehabilitation and resettlement, including providing fair compensation to affected communities.
# 4. Maintain accurate records and submit reports to the DGMS as required by law.
#
# **RELATED PROVISIONS**
#
# * The Environment (Protection) Act, 1986: Provides a framework for environmental protection and conservation.
# * The Forest Conservation Act, 1980: Regulates the use of forest land for mining purposes.
# * The Public Liability Insurance Act, 1991: Provides insurance coverage for damages caused by mining activities.
#
# **CORRECTIVE ACTIONS REQUIRED**
#
# Immediate Actions:
#
# * Conduct a thorough environmental impact assessment to identify potential risks and develop strategies for mitigation.
# * Implement measures to prevent accidents, including regular safety inspections and training for workers.
# * Comply with regulations on rehabilitation and resettlement, including providing fair compensation to affected communities.
#
# Systemic Improvements:
#
# * Develop and implement a comprehensive environmental management plan.
# * Conduct regular safety audits and inspections to identify potential risks and develop strategies for mitigation.
# * Provide training and awareness programs for workers on environmental and health and safety standards.
#
# Compliance Verification:
#
# * Conduct regular audits and inspections to ensure compliance with environmental and health and safety regulations.
# * Maintain accurate records and submit reports to the DGMS as required by law.
# * Develop and implement a system for tracking and monitoring compliance with regulations.
#
# **PREVENTIVE MEASURES**
#
# * Develop and implement Standard Operating Procedures (SOPs) for environmental management and health and safety standards.
# * Install safety equipment and systems to prevent accidents and protect workers.
# * Conduct regular training and awareness programs for workers on environmental and health and safety standards.
# * Establish a system for monitoring and tracking compliance with regulations.
# --------------------------------------------------------------------------------
#
#  SOURCES:
# ================================================================================
#
# [1] DGMS_Annual_Report_2014_Eng-09.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 346/669
#     Preview: . Environmental Management:- Mine environment monitoring and control; EMP (Environment Management Plan), mine closure plan; R&R (rehabilitation and re...
#
# [2] DGMS_Annual_Report_2014_Eng-09.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 573/669
#     Preview: . Environmental Management:- Mine environment monitoring and control; EMP (Environment Management Plan), mine closure plan; R&R (rehabilitation and re...
#
# [3] THE COAL MINES( CONSERVATION AND DEVELOPMENT) AMENDMENT RULES 2011.pdf
#     Type: Regulation
#     Subject: Coal Mining
#     Year: 2011
#     Chunk: 44/45
#     Preview: . Rule 12 (1) (ii) (d): construction of dams; Rule 12 (1) (ii) (e): artificial barriers. Rule 12 (1) (iii): Special mining techniques obviating sand s...
#
# [4] DGMS_Annual_Report_2014_Eng-09.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 289/669
#     Preview: . Personal Management :- Selection; training and development of human resources; conflict management; sources of conflict; dealing with conflict, moti...
#
# [5] DGMS_Annual_Report_2014_Eng-09.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 616/669
#     Preview: . Environmental Management :- Mine Environment monitoring and control; EMP (Environment Management Plan); mine closure plan; R&R (rehabilitation and r...
#
# ================================================================================
#
#
# ================================================================================
# Query 2/3
# ================================================================================
#
# ================================================================================
#  QUESTION: What are the requirements for mine closure?
# ================================================================================
#
#  Searching documents and generating answer...
#
#  ANSWER:
# --------------------------------------------------------------------------------
# **MINE CLOSURE REQUIREMENTS**
#
# **INCIDENT OVERVIEW**
# The mine closure requirements are specified to ensure the safe and controlled shutdown of mining operations.
#
# **LEGAL VIOLATIONS IDENTIFIED**
# None identified in the provided context.
#
# **APPLICABLE LEGAL FRAMEWORK**
#
# 1. **Primary Legislation (Mines Act 1952)**
#     • Section 8: Before a mine is abandoned or the workings thereof discontinued, the owner, agent or manager shall cause the top or entrance of every shaft, incline or other opening into the mine to be fenced by a structure of a permanent character sufficient effectively to prevent persons falling into or entering the same.
#     • Section 129: Examination by sirdars – Every place in a mine whether belowground or in opencast workings, including travelling roadways and landings, where work is carried on or where persons are stationed or required to pass shall be placed under the charge of a sirdar or other competent person.
#
# 2. **Subordinate Regulations (MMR 1961, CMR 2017)**
#     • Section 111: Working near mine boundaries – The owner, agent or manager of every mine shall fix boundaries of the mine. Notwithstanding anything contained in sub-regulation (2), the boundaries shall not be changed except with the permission of the Chief Inspector in writing and subject to such conditions as he may specify therein.
#     • Section 121: Working near mine boundaries in belowground mines – The owner, agent or manager of every belowground mine shall have fixed boundaries of the mine and notwithstanding anything contained in sub-regulation (2), these shall not be changed except with the express permission of the Chief Inspector in writing and subject to such conditions as he may specify therein.
#
# 3. **DGMS Circulars/Technical Guidelines**
#     None mentioned in the provided context.
#
# **ROOT CAUSE ANALYSIS**
# None identified in the provided context.
#
# **LEGAL CONSEQUENCES & LIABILITIES**
# None identified in the provided context.
#
# **CORRECTIVE ACTIONS REQUIRED**
# None identified in the provided context.
#
# **PREVENTIVE MEASURES**
# To ensure safe mine closure, the following preventive measures can be taken:
#
# - Standard Operating Procedures (SOPs) to implement for mine closure and rehabilitation.
# - Safety equipment/systems to install for securing mine entrances and preventing unauthorized access.
# - Training programs to conduct for mine closure and rehabilitation personnel.
# - Monitoring mechanisms to establish for ensuring compliance with mine closure regulations.
#
# **DIRECT ANSWER**
# The mine closure requirements are specified in the Mines Act 1952, specifically in Section 8 and Section 129, to ensure the safe and controlled shutdown of mining operations.
#
# **LEGAL BASIS**
# - Mines Act 1952 - Section 8: Before a mine is abandoned or the workings thereof discontinued, the owner, agent or manager shall cause the top or entrance of every shaft, incline or other opening into the mine to be fenced by a structure of a permanent character sufficient effectively to prevent persons falling into or entering the same.
# - Mines Act 1952 - Section 129: Examination by sirdars – Every place in a mine whether belowground or in opencast workings, including travelling roadways and landings, where work is carried on or where persons are stationed or required to pass shall be placed under the charge of a sirdar or other competent person.
#
# **DETAILED EXPLANATION**
# The mine closure requirements are specified to ensure the safe and controlled shutdown of mining operations. The owner, agent or manager of the mine is responsible for ensuring that the mine is closed in a manner that prevents harm to people and the environment.
#
# **COMPLIANCE REQUIREMENTS**
# - The owner, agent or manager of the mine shall cause the top or entrance of every shaft, incline or other opening into the mine to be fenced by a structure of a permanent character sufficient effectively to prevent persons falling into or entering the same.
# - The mine shall be placed under the charge of a sirdar or other competent person before it is abandoned or the workings thereof discontinued.
# - The boundaries of the mine shall not be changed except with the permission of the Chief Inspector in writing and subject to such conditions as he may specify therein.
#
# **PRACTICAL GUIDANCE**
# - The mine owner, agent or manager shall ensure that the mine is closed in a manner that prevents harm to people and the environment.
# - The mine owner, agent or manager shall ensure that the top or entrance of every shaft, incline or other opening into the mine is fenced by a structure of a permanent character sufficient effectively to prevent persons falling into or entering the same.
# - The mine owner, agent or manager shall ensure that the mine is placed under the charge of a sirdar or other competent person before it is abandoned or the workings thereof discontinued.
#
# **RELATED PROVISIONS**
# - Cross-references to connected regulations.
# - Additional considerations for mine closure and rehabilitation.
# --------------------------------------------------------------------------------
#
#  SOURCES:
# ================================================================================
#
# [1] COAL MINES REGULATION 2017.pdf
#     Type: Regulation
#     Subject: Coal Mining
#     Year: 2017
#     Chunk: 361/639
#     Preview: . (8) Before a mine is abandoned or the workings thereof discontinued, the owner, agent or manager shall cause the top or entrance of every shaft, inc...
#
# [2] THE METALLIFEROUS MINES REGULATIONS 1961.pdf
#     Type: Regulation
#     Subject: General Mining
#     Year: 1961
#     Chunk: 296/528
#     Preview: . (2) If the owner fails to construct such protective works within the time specified in the order, the Chief Inspector may get the works executed by ...
#
# [3] COAL MINES REGULATION 2017.pdf
#     Type: Regulation
#     Subject: Coal Mining
#     Year: 2017
#     Chunk: 340/639
#     Preview: . (2) If the owner fails to construct such protective works within the time specified in the order referred to in sub-regulation (1), the Chief Inspec...
#
# [4] DGMS_Annual_Report_2014_Eng-13.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 627/1512
#     Preview: . 1.8.1(b) Ensure that contractors are familiar with the relevant parts of the statutes, health and safety management system and are provided with cop...
#
# [5] DGMS_Annual_Report_2014_Eng-13.pdf
#     Type: Report
#     Subject: Safety & Inspection
#     Year: 2014
#     Chunk: 1385/1512
#     Preview: . 1.8.1(b) Ensure that contractors are familiar with the relevant parts of the statutes, health and safety management system and are provided with cop...
#
# ================================================================================
#
#
# ================================================================================
# Query 3/3
# ================================================================================
#
# ================================================================================
#  QUESTION: What are the provisions for compensation in case of mining accidents?
# ================================================================================
#
#  Searching documents and generating answer...
#
#  ANSWER:
# --------------------------------------------------------------------------------
# **INCIDENT OVERVIEW**
# On 29.12.2016, a slope failure occurred at the Dahernangi Patch of Rajmahal Opencast Mine, resulting in a fatal accident. The incident highlights the importance of adhering to safety regulations to prevent such tragedies.
#
# **LEGAL VIOLATIONS IDENTIFIED**
#
# • **Regulation 106(3) of the Metalliferous Mines Regulations, 1961**: The persons were not engaged at the place where sides in the excavation were not adequately benched, sloped or secured so as to prevent danger from fall of sides.
#   Required: Adequate benching, sloping, or securing of sides to prevent danger from fall of sides.
#   Violation: Sides were not adequately secured, leading to a slope failure.
#   Risk: Loss of life and damage to property.
#
# • **Section 17(1) of the Mines Act, 1952**: The mine was not placed under the charge of a duly qualified manager to ensure that all work in the mine was carried on in accordance with the provisions of the Mines Act, and of the regulations, rules, bye-laws and orders made there-under.
#   Required: A duly qualified manager to oversee mine operations.
#   Violation: The mine was not placed under a qualified manager, leading to non-compliance with safety regulations.
#   Risk: Loss of life and damage to property.
#
# • **Section 18(4) of the Mines Act, 1952**: The scaffold or rope was not suitably fixed and sufficiently strong to prevent falling.
#   Required: A scaffold or rope that is suitably fixed and sufficiently strong to prevent falling.
#   Violation: The scaffold or rope was not fixed or strong enough, leading to a fall.
#   Risk: Loss of life and injury.
#
# • **Regulation 34(1)(a) of the Metalliferous Mines Regulations, 1961**: The mine was not placed under the charge of a duly qualified manager to ensure that all work in the mine was carried on in accordance with the provisions of the Mines Act, and of the regulations, rules, bye-laws and orders made there-under.
#   Required: A duly qualified manager to oversee mine operations.
#   Violation: The mine was not placed under a qualified manager, leading to non-compliance with safety regulations.
#   Risk: Loss of life and damage to property.
#
# • **Regulation 44 of the Metalliferous Mines Regulations, 1961**: The job was not supervised to ensure that work was carried out as required.
#   Required: Supervision to ensure work is carried out as required.
#   Violation: The job was not supervised, leading to non-compliance with safety regulations.
#   Risk: Loss of life and damage to property.
#
# • **Regulation 116 of the Metalliferous Mines Regulations, 1961**: A mining mate was not appointed to personally supervise operations connected with the mine and ensure proper observance of the provisions of the Mines Act, 1952, and of the rules and regulations framed there-under.
#   Required: A mining mate to supervise operations and ensure compliance with safety regulations.
#   Violation: A mining mate was not appointed, leading to non-compliance with safety regulations.
#   Risk: Loss of life and damage to property.
#
# **APPLICABLE LEGAL FRAMEWORK**
#
# 1. **Primary Legislation: Mines Act, 1952**
#    • **Section 17(1)**: Requires the mine to be placed under the charge of a duly qualified manager to ensure compliance with safety regulations.
#    • **Section 18(4)**: Requires a scaffold or rope to be suitably fixed and sufficiently strong to prevent falling.
# 2. **Subordinate Regulations: Metalliferous Mines Regulations, 1961**
#    • **Regulation 34(1)(a)**: Requires the mine to be placed under the charge of a duly qualified manager to ensure compliance with safety regulations.
#    • **Regulation 44**: Requires supervision to ensure work is carried out as required.
#    • **Regulation 106(3)**: Requires sides in the excavation to be adequately benched, sloped, or secured to prevent danger from fall of sides.
#    • **Regulation 116**: Requires a mining mate to be appointed to supervise operations and ensure compliance with safety regulations.
# 3. **DGMS Circulars/Technical Guidelines**: Not mentioned in the provided context.
#
# **ROOT CAUSE ANALYSIS**
#
# • **Procedural gaps**: The mine was not placed under a duly qualified manager, and a mining mate was not appointed to supervise operations.
# • **Supervisory lapses**: The job was not supervised to ensure work was carried out as required.
# • **Communication breakdowns**: Not mentioned in the provided context.
# • **Training/competency issues**: Not mentioned in the provided context.
#
# **LEGAL CONSEQUENCES & LIABILITIES**
#
# • **Employer/Management Responsibilities**: Under the Mines Act, 1952, the employer/management is responsible for ensuring compliance with safety regulations.
#
# --------------------------------------------------------------------------------
#
#  SOURCES:
# ================================================================================
#
# [1] SANKET NON-COAL MINES 2016-22.pdf
#     Type: Document
#     Subject: Coal Mining
#     Year: 2016
#     Chunk: 484/1096
#     Preview: : Key Evaluation of Trends in Non-Coal Mine Accidents SANKET mine and sfety of persons employed in the mine was ensured in every respect, as required ...
#
# [2] Rajmahal Court of Enquiry Report.pdf
#     Type: Report
#     Subject: Legal & Judicial
#     Year: Unknown
#     Chunk: 127/457
#     Preview: . The Hon’ble Court is requested to consider and recommend payment of an ex-gratia amount of Rs. 30 lakhs to the legal heirs of the victim. (v) The Co...
#
# [3] SANKET NON-COAL MINES 2016-22.pdf
#     Type: Document
#     Subject: Coal Mining
#     Year: 2016
#     Chunk: 705/1096
#     Preview: . 222 Statistical Analysis & Numbers: Key Evaluation of Trends in Non-Coal Mine Accidents SANKET Had, (i) the persons not been engaged at the place wh...
#
# [4] SANKET NON-COAL MINES 2016-22.pdf
#     Type: Document
#     Subject: Coal Mining
#     Year: 2016
#     Chunk: 1055/1096
#     Preview: . Had, (i) it been ensured and protected on scaffold or rope suitably fixed and sufficiently strong to prevent from falling as required under Section ...
#
# [5] SANKET NON-COAL MINES 2016-22.pdf
#     Type: Document
#     Subject: Coal Mining
#     Year: 2016
#     Chunk: 410/1096
#     Preview: : Key Evaluation of Trends in Non-Coal Mine Accidents SANKET orders made there-under, whereby safety of the mine as well as life and safety of persons...
#
# ================================================================================

# %%
# ============================================================================
# END OF NOTEBOOK
# ============================================================================
print("\n" + "="*80)
print(" NOTEBOOK COMPLETED SUCCESSFULLY!")
print("="*80)
print("\n Next Steps:")
print("   1. Review the answers above")
print("   2. Modify sample questions in Cell 7")
print("   3. Use Cell 9 for single custom questions")
print("   4. Use Cell 10 for batch questions")
print("   5. Check /kaggle/working/queries_log.json for saved results")
print("\n" + "="*80 + "\n")
# Out:
# ================================================================================
#  NOTEBOOK COMPLETED SUCCESSFULLY!
# ================================================================================
#
#  Next Steps:
#    1. Review the answers above
#    2. Modify sample questions in Cell 7
#    3. Use Cell 9 for single custom questions
#    4. Use Cell 10 for batch questions
#    5. Check /kaggle/working/queries_log.json for saved results
#
# ================================================================================
